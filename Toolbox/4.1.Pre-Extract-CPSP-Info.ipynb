# %% [markdown]
# # Step Four: 1. Pre-Extract "CPSP" information of Alloy from Papers

# %% [markdown]
# ## &#9679; "Composition-Processing-Structure-Performance" (CPSP) Information of Alloy
# #### 1. **Letter "C" in "CPSP" (C)**: Alloy Composition, Alloy_Designation, and Alloy_Formula;
# #### 2. **First letter "P" in "CPSP" (P1)**: Processing routes/Heat treatment (Operation actions, Conditions, and Corresponding parameters in each period);
# #### 3. **Letter "S" in "CPSP" (S)**: Structure/Microstructure (Average Grain Size, Structure type(bcc/fcc/hcp), Strengthening Phase, Characteristics Of Precipitation
# #### (Finer/Uniformly), Grain Boundary(High-angle/Small-angle);
# #### 4. **Second letter "P" in "CPSP" (P2)**: Performance/Properties (Mechancial Properties: σb, σs, δ, σbc, σbb, Young’s modulus, shear modulus, poisson’s ratio,
# #### flexural modulus, hardness, reduction of area, conductivity ... Corrosion Properties: Ecorr, Icorr, KISCC, ISSRT ... Fracture Properties: KIC, toughness,
# #### fatigue strength, fracture mode (brittle/ductile) ... Strengthening Mechanism: grain strengthening, dislocation strengthening, precipitation strengthening,
# #### solid–solution strengthening.

# %% [markdown]
# ## &#9679; Extract "CPSP" Inforamtion in the field of metallurgy from Literature by Prompt Engineering
# #### (Multiple Publishers: Elsevier, Springer Nature, Royal Soc Chemistry)
# #### **Note:** 1. Relevant information on Composition "C" and Processing "P1" generally distributed in "Experimental Methods" Section.
# #### **Note:** 2. Relevant information on Structure "S" and Performance "P2" generally distributed in "Results and Discussions" Section.
# #### This is the code for Alloy, and you can If modify the prompts and examples in "Prompt+Example" folder to process your own data.

# %% [markdown]
# ### **Step 4.1.1 Pre-Processing**:
# #### **Aims**: Get structured pieces of information from original papers (Json file), reduce GPT usage cost/time and improve extraction accuracy as possible.
# #### **HOW TO USE**: Change key_words according to the sections you want to extract. Examples are provided in annotations labeled by """
#
# ### **Step 4.1.2 Pre-Extracting by prompt engineering**:
# #### **Aims**: Extract "C"+"P1" from pre-extracted "Experimental Methods" sections by prompt engineering,
# #### Extract "S", "P2" from "Results and Discussions" sections by prompt engineering,
# #### Integrate Table-Info by prompt engineering,
# #### **HOW TO USE**: Prompts used in the case are all provided in "Prompt+Example/Prompt.txt", and examples for GPT provided in "Prompt+Example/Example",
# #### Fill in your own API_key and base_url, and modify the prompts and examples based on your task.

# %% [markdown]
# ## 4.1.1 Pre-Processing

# %%
import os
import json
import chardet  # Import chardet library for encoding detection

# Set input and output paths
input_path = 'Data/TextJSON'  # Input path
output_path = 'Data/ExperimentalMethod' # Output path

# Detect file encoding
def detect_file_encoding(file_path):
    with open(file_path, 'rb') as f:
        raw_data = f.read()
        result = chardet.detect(raw_data)
        return result['encoding']

def process_text_file(input_file_path, output_file_path):
    print(input_file_path)
    detected_encoding = detect_file_encoding(input_file_path)
    try:
        # Use the detected encoding to read the JSON file
        with open(input_file_path, "r", encoding=detected_encoding) as f:
            content = json.load(f)
        
        # Check and filter 'Sections'
        if isinstance(content.get("Sections"), list):
            filtered_sections = [
            ]
            for section in content["Sections"]:
                # print(section.get('name'))
                # print(section["content"])
                if isinstance(section['content'][0],dict):
                    # print("dict")
                    # print(section)
                    flag = False
                    """ 
                    # keywords for Experimental Methods 
                    for key_word in ["test", "Test", "tests", "Tests", "Procedures", "procedures", "procedure","Procedure", "heat-treatment", "Heat-treatment", 
                    "Heat treatment","heat treatment","experiment", "Experiment", "Experimental","experimental", "methodology", "method", "Methodology", "Method", 
                    "material", "processing", "Material", "Processing", "preparation", "Preparation", "process", "Process", "materials", "Materials", 
                    "sample", "samples", "Sample", "Samples"]:
                    
                    # keywords for Results & Discussions
                    for key_word in ["heat-treatment","Heat-treatment","heat treatment","Heat treatment", "results", "Results", "result", "Result", 
                    "discussions", "Discussions", "Discussion", "discussion", "microstructure", "Microstructure", "microstructural", 
                    "Microstructural", "analysis", "Analysis", "Analytical", "analytical", "performance", "Performance", "Properties", 
                    "properties", "Comparsion", "comparsion","Mechanism", "mechanism", "Mechanisms", "mechanisms", "nanostructure", 
                    "Nanostructure", "Characterization", "characterization"]:
                    
                    # keywords for Abstarct
                    for key_word in ["Abstarct", "abstarct"]:
                    """
                    for key_word in ["XXX","YYY"]: ### keywords of sections Your want to extract
                                if key_word in section.get('name'):
                                    filtered_sections.append(section)
                                    flag = True
                                    
                    if flag:
                        continue
                    for c in section['content']:
                        # print("c",c)
                        # print(c.get("name"))
                        """
                        # keywords for Experimental Methods 
                        for key_word in ["test", "Test", "tests", "Tests", "Procedures", "procedures", "procedure","Procedure", "heat-treatment", "Heat-treatment", 
                        "Heat treatment","heat treatment","experiment", "Experiment", "Experimental","experimental", "methodology", "method", "Methodology", "Method", 
                        "material", "processing", "Material", "Processing", "preparation", "Preparation", "process", "Process", "materials", "Materials", 
                        "sample", "samples", "Sample", "Samples"]:
                        # keywords for Results & Discussions
                        for key_word in ["heat-treatment","Heat-treatment","heat treatment","Heat treatment", "results", "Results", "result", "Result", 
                        "discussions", "Discussions", "Discussion", "discussion", "microstructure", "Microstructure", "microstructural", 
                        "Microstructural", "analysis", "Analysis", "Analytical", "analytical", "performance", "Performance", "Properties", 
                        "properties", "Comparsion", "comparsion","Mechanism", "mechanism", "Mechanisms", "mechanisms", "nanostructure", 
                        "Nanostructure", "Characterization", "characterization"]:
                        # keywords for Abstarct
                        for key_word in ["Abstarct", "abstarct"]:
                        """
                        for key_word in ["XXX","YYY"]: ### keywords of sections Your want to extract
                                if key_word in c.get('name'):
                                    filtered_sections.append(c)
                                    print(c)
                                    break
                elif isinstance(section['content'][0],str):
                    # print("str")
                # if isinstance(section[0],dict)
                    # print(section)
                    # print(section.get("name"))
                    """
                    # keywords for Experimental Methods 
                    for key_word in ["test", "Test", "tests", "Tests", "Procedures", "procedures", "procedure","Procedure", "heat-treatment", "Heat-treatment", 
                    "Heat treatment","heat treatment","experiment", "Experiment", "Experimental","experimental", "methodology", "method", "Methodology", "Method", 
                    "material", "processing", "Material", "Processing", "preparation", "Preparation", "process", "Process", "materials", "Materials", 
                    "sample", "samples", "Sample", "Samples"]:
                    # keywords for Results & Discussions
                    for key_word in ["heat-treatment","Heat-treatment","heat treatment","Heat treatment", "results", "Results", "result", "Result", 
                    "discussions", "Discussions", "Discussion", "discussion", "microstructure", "Microstructure", "microstructural", 
                    "Microstructural", "analysis", "Analysis", "Analytical", "analytical", "performance", "Performance", "Properties", 
                    "properties", "Comparsion", "comparsion","Mechanism", "mechanism", "Mechanisms", "mechanisms", "nanostructure", 
                    "Nanostructure", "Characterization", "characterization"]:
                    # keywords for Abstarct
                    for key_word in ["Abstarct", "abstarct"]:
                    """
                    for key_word in ["XXX","YYY"]: ### keywords of sections Your want to extract
                            if key_word in section.get('name'):
                                filtered_sections.append(section)
                                # print(section)
                                break
               
            print("filterd:",filtered_sections)
            content["Sections"] = filtered_sections
            
            # Ensure output directory exists
            os.makedirs(output_path, exist_ok=True)
            
            # Write to output file
            with open(output_file_path, "w", encoding="utf-8") as f:
                json.dump(content, f, indent=4, ensure_ascii=False)
            print(f"Processed and saved: {output_file_path}")
        else:
            print(f"Warning: 'Sections' in {input_file_path} is not a list. Skipping file.")
            
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON in {input_file_path}: {e}")
    except UnicodeDecodeError as e:
        print(f"Error with encoding {detected_encoding} in {input_file_path}: {e}. Trying UTF-8 instead.")
        # Attempt to read the file using UTF-8 encoding if the detected one fails
        try:
            with open(input_file_path, "r", encoding="utf-8") as f:
                content = json.load(f)
            # Continue processing if read is successful
        except Exception as e:
            print(f"Unexpected error processing {input_file_path} with UTF-8: {e}")
    except IOError as e:
        print(f"Error processing file {input_file_path}: {e}")
    except Exception as e:
        print(f"Unexpected error processing {input_file_path}: {e}")

def main():
    # Ensure output directory exists
    os.makedirs(output_path, exist_ok=True)
    
    # Process all JSON files in the folder
    print("Starting to process files...")
    processed_count = 0
    
    for file in os.listdir(input_path):
        if file.endswith(".json"):  # Process only JSON files
            input_file_path = os.path.join(input_path, file)
            output_file_path = os.path.join(output_path, file)
            process_text_file(input_file_path, output_file_path)
            processed_count += 1
    
    print(f"\nProcessing complete. Files processed: {processed_count}")

if __name__ == "__main__":
    main()
# Out:
# Starting to process files...
# Data/TextJSON/10.1557-s43578-022-00691-2.json
# filterd: [{'name': 'Material and methods', 'content': ["Pure metal sheets of titanium, zirconium, niobium, and tantalum (purity 99.5%, 99.2%, 99.9%, 99.95%, respectively) were purchased from The Nilaco Corporation. They were cut into circular plates of 3\xa0mm in diameter and 0.2\xa0mm thick. They were mechanically mirror-polished with alumina powder of 0.3\xa0µm and ultrasonically rinsed in acetone and ethanol. They were heated at 400–800\xa0°C for 3.6 ks in the air for oxidation. The surface morphology of the samples was observed with scanning electron microscopy (SEM, JXA-6300P, JEOL, Japan). The surface film formed by the heat treatment was examined by X-ray diffractometry (XRD) using a diffractometer (X’pert pro, PANalytical, Japan) operating at 45\xa0kV and 40\xa0mA. The average (arithmetical mean) surface roughness, Ra, and length measured along the surface roughness contour, L', were analyzed using a surface roughness tester (SE-3F, Kosaka Laboratory Ltd.). The surface area ratio, r , was evaluated using the following equation: L is the length being measured along a perfectly smooth sample surface. The water contact angle (WCA) of the sample, representing wettability, was also evaluated.", "The samples were sterilized at 121\xa0°C for 1.2 ks for the cell culture experiments. MC3T3-E1 osteoblast-like cells were cultured in a 96-well polystyrene cell culture plate for 3.6 ks, 21.6 ks, and 86.4 ks in Eagle’s minimal essential medium (MEM-α) (Wako Pure Chemical Industrials Co. Ltd., Japan) with 10% fetal bovine serum (FBS) and 1% penicillin–streptomycin and incubated in a humidified atmosphere of 5% CO2 at 37\xa0°C. The initial density of cells in each culture plate well was 2000 cells/well. After culturing, these samples were rinsed with phosphate-buffered saline (PBS) and fixed with 4% paraformaldehyde, and then stained with a combination of two fluorescent dyes. One dye was phalloidin, which stains the actin of a cell, and the other dye was DAPI, which stains the cell nucleus. The morphology and number of cells were evaluated using a fluorescence microscope (BX53, Olympus). The number of cells on the surface of the sample in a 1-mm2 square area was counted by using the image analysis software, the Image J . The cell number was counted in three areas in each sample; then, the average value was obtained. The “cell proliferation” value was defined as the number of cells after 24\xa0h culture divided by that after 6\xa0h culture. The area of a cell (cell area, C.A.) was also measured for cell size evaluation after a 6\xa0h culture. Cell shape was quantified via the shape index (S.I.\u2009=\u20094πA/p2)  using the Image J software. The A is the cell area, and the p is the perimeter of the cell. The shape index for the spherical cells will be one, while that for elongated morphology will be less than one. Statistical significance was evaluated at a p\u2009<\u20090.05 level. The graph's data points and error bars represent the mean values and standard deviation, respectively."]}]
# Processed and saved: Data/ExperimentalMethod/10.1557-s43578-022-00691-2.json
# Data/TextJSON/10.1016-j.actamat.2005.02.010.json
# filterd: [{'content': ['The composition of NIMONIC PE16 is in at.%: Ni 41, Fe 34, Cr 17, Mo 2.0, Ti 1.5, Al 2.6, C 0.25. The preparation of the tensile specimens was essentially the same as in the previous investigation . Cylindrical polycrystals with two different grain sizes d were produced by thermo-mechanical treatments. d was defined as the average spacing of GBs along straight lines; twin boundaries were not counted as GBs . All relevant data have been compiled in Table 1 . d was 6.1 and 265 μm. All specimens were given a 2-hour long γ′-nucleation treatment at 973 K and aged for t 1 = 51.5 h at T 1 = 1079 K. The resulting γ′-precipitate dispersion was: f 1 = (0.061 ± 0.009), r 1 = (25.0 ± 1.5) nm. The latter two data were calculated from the published functions f(T) and r(T, t) . The square lattice spacing L min1 defined in Section 1 in connection with relation (4) equals 155 nm. The two values quoted in the following for the PFZ-widths w′ have been taken from the literature ; they are averages over about six GBs. The widths of individual PFZs in a specimen vary considerably. w1′=103nm of the finely grained (d = 6.1 μm) polycrystals was below the limit given by relation (4) for softening by PFZs: w1′ equaled only 0.8 · (L min1 − r 1). w1′=650nm of the coarsely grained (d = 265 μm) specimens well exceeded the limit: w1′=5.0·(Lmin1-r1) . Hence these two types of polycrystals are designated NO-PFZi (d = 6.1 μm) and PFZi (d = 265 μm). i indicates the number of aging treatments given to the respective specimens. i equals 1 for those aged only at 1079 K and i equals 2 for those which were double aged. The second aging treatment was 42.5 h at 949 K. It raised f 1 and r 1 to f1′≈0.07andr1′≈26nm, respectively, and produced a second fine γ′-precipitate dispersion characterized by f 2 ≈ 0.04 and r 2 ≈ 4 nm. This will be detailed in Section 3.1.', 'The temperatures and durations of the two aging treatments were chosen such that the NO-PFZ1-specimens were in the peak-aged state, but close to the over-aged one (, Section 2.2) and such that the second γ′-precipitate dispersion was fine. There were many fine γ′-precipitates in between the large ones grown at 1079 K and in the PFZs produced at 1079 K (Fig. 1 ). Hypothetical monomodal specimens which contained only the fine (f 2, r 2) γ′-precipitates throughout would be in the under-aged state.', {'content': ['The nominal gauge dimensions of the specimens were 6 mm length and 2 mm diameter. Four identically prepared specimens of each type were tensile tested at 295 K at the elongation rate 1.7 μm s−1 . Only every other specimen was strained to fracture; the deformation of the others was stopped at about 0.02 plastic strain. After unloading the dislocation structures of the latter specimens were studied by TEM (Section 2.2). The yield strength σ y, the ultimate tensile strength σ u, and the plastic strain ε f at fracture were evaluated. σ y is the normal stress which produces 0.002 plastic strain and σ u is the maximum load carried by the specimen divided by its cross-sectional area before the deformation. Analogously ε f is the plastic elongation divided by the original gauge length. These simple technical definitions of σ u and ε f were adopted because the plastically active volume of the specimens is difficult to determine if they form constrictions. The average experimental results for σ y, σ u, and ε f have been compiled in Table 1. The standard deviations are 0.7%, 2.2%, and 7.4%, respectively. Evidently the error limits of ε f are rather large; this is at least partially due to the fact that only two specimens were tensile tested to fracture. The agreement of the present results with those published by Krol et al. is within ±3.3% for σ y(NO-PFZ1), σ y(PFZ1), σ u(NO-PFZ1), and ε f(NO-PFZ1), within ±7.6% for σ u(PFZ1), and within ±21% for ε f(PFZ1).'], 'name': 'Tensile tests', 'type': 'ce_section'}, {'content': ['Two types of TEM investigations were carried out for bimodal specimens:  ...
# Processed and saved: Data/ExperimentalMethod/10.1016-j.actamat.2005.02.010.json
# Data/TextJSON/10.1016-j.actamat.2007.08.033.json
# filterd: [{'content': ['The nominal composition of the alloy used in this study is Mg97Zn1Gd2 (at.%). Ingots were prepared by high-frequency induction heating in an argon atmosphere. Solution treatment was carried out at 793 K for 2 h in air. The specimens were then quenched in water at room temperature.', 'The microstructure of the alloys was investigated using X-ray diffractometry (XRD), scanning electron microscopy (SEM) and transmission electron microscopy (TEM) with a JEM-2000FX operating at 200 kV and a JEM-4000EX operating at 400 kV. HAADF-STEM images were obtained using a 300 kV field emission electron microscope (JEM-3000F). TEM specimens were cut from the aged sample and thinned by mechanical polishing followed by ion-milling.', 'The hardness of the specimens was measured by Vicker’s micro-hardness testing. Tensile tests were carried out using an Instron-type tensile testing machine at room and elevated temperatures with an initial strain rate of 5 × 10−4 s−1. The dimensions of tensile testing specimens were 2.5 mm in diameter by 15 mm long.'], 'name': 'Experimental procedure', 'type': 'ce_section'}, {'content': ['Fig. 1 shows SEM images of as-cast and solution-treated Mg97Zn1Gd2 alloys and selected area electron diffraction (SAED) patterns obtained from the secondary phase (bright contrast in the SEM image) of the as-cast alloy. Solution treatment was carried at 793 K for 2 h. The SAED patterns in Fig. 1c–e reveal that the secondary phase in the as-cast Mg–Zn–Gd alloy is a Mg3Gd-type compound (D03, a = 0.720 nm). A chemical analysis by EDS showed the averaged compositions of Mg3Gd type compound are Mg–23 ± 2 at.% Gd–21 ± 3 at.% Zn. Mg3Gd-type compound particles are often observed in the α-Mg matrix and in grain boundaries. After solution heat treatment, the volume fraction of the Mg3Gd-type compound decreases.', 'Fig. 2 shows the isothermal annealing response of Vicker’s micro-hardness in the solution-treated Mg97Zn1Gd2 alloy. At an aging temperature of 473 K, the specimen exhibits remarkable age hardening. Its hardness reaches about 128Hv0.1. However, at aging temperatures >573 K, the hardness of the specimens remains <100Hv0.1 during long-term annealing.', 'TEM observations were carried out in order to elucidate the aging behavior of the alloy at various temperatures. β′-phase precipitation was observed after 60 h aging at 473 K. Figs. 3 a,b and c,d show TEM images and electron diffraction (ED) patterns of the peak-aged specimen (473 K for 150 h), taken with the incident beam parallel to [0 0 1]matrix and [1 1 0]matrix. The β′ precipitates elongate along the c-axis of the α-Mg matrix and extend along the [1 2 0]matrix-type directions of the α-Mg matrix. The ED patterns reveal that the β′-phase (Mg7Gd , orthorhombic, a = 0.64 nm, b = 2.25 nm, c = 0.52 nm) precipitates in the α-Mg matrix with the orientation relationship: [001]matrix//[100]β′,{100}matrix//(010)β′. This agrees with previous results where the peak aging hardness is thought to be due to the precipitation of β′-phases . In addition to the β-phase precipitation, β1-phase precipitation is also observed after 150 h annealing at 473 K. In the previous studies, it was reported that the β1-phase in Mg–Gd binary alloy has an fcc structure . Further research on the β1-phase crystalline structure in Zn-containing Mg–Gd alloy is now under way, and the results will be reported elsewhere. After annealing at 473 K for 250 h, plate-like precipitates of the β-phase (Mg5Gd , fcc, a = 2.27 nm) are observed in the over-aged specimen with the following orientation relationship: [1 1 0]matrix//[1 1 1]β and (0 0 1)matrix//(1 1 0)β. This orientation relationship is the same as that reported for the stable β-phase in Mg–Gd binary alloys .', 'Fig. 4 shows a TEM micrograph and SAED pattern of the Mg97Zn1Gd2 ternary alloy aged at 573 K for 10 h. The incident electron beam direction is parallel to the [1 1 0]matrix. A large number of stacking faults (SF) are observed in the Mg97Z ...
# Processed and saved: Data/ExperimentalMethod/10.1016-j.actamat.2007.08.033.json
# Data/TextJSON/10.1016-j.jallcom.2018.02.271.json
# filterd: [{'content': [{'content': ['The Ti microparticles are utilized to improve the wettability between TiN nanoparticles and aluminum liquids, and the composite refiner is named as TiN/Ti refiner []. As shown in Fig.\xa01 , the ball-milled TiN nanoparticles were well-dispersed and supported onto the surfaces of the Ti microparticles.', 'The lab-made Al-Zn-Mg-Cu alloys (Al-7.0Zn-2.5Mg-2.5Cu, in the mass ratio) were synthesized in the graphite crucible of the resistance heated furnace via melting commercially available high-purity Al, Zn, Mg and Cu by the above-mentioned mass ratio. The appropriate amount of TiN/Ti refiner was stirred into the Al-Zn-Mg-Cu melts at the temperature of 730\u202f°C and held the temperature for 10\u202fmin. Then the corresponding melts were poured into the permanent mould (the size is given in Fig.\xa02 ). The TiN/Ti refiner (or Ti powder to produce contrastive samples) was added in mass ratio of 0.5\u202fwt % of the above-mentioned alloys.', 'The samples cut as Φ 30\u202f×\u202f13 from the ingot whose size is shown in Fig.\xa02 were homogenized at the temperature of 470\u202f°C for 24\u202fh and the hot extrusion was performed at 400\u202f°C through an indirect extrusion method under the ram speed of 10\u202fmm\u202fs−1 together with an extrusion ratio of 6.9. Then, the obtained cylindrical bars for hardness and strength tests were solid solution treated at 473\u202f°C for 2\u202fh, quenching in water at 60\u202f°C, and artificial aging at 120\u202f°C for 0–120\u202fh, successively. The specific size of the lab-made tensile specimen of the above-mentioned Al-Zn-Mg-Cu alloy is presented in Fig.\xa03 .'], 'name': 'Preparation of Al-Zn-Mg-Cu alloy specimens', 'type': 'ce_section'}, {'content': ['Metallographic analysis specimens were mechanically polished and etched in standard routines []. The microstructures were observed by the optical microscope (DMM-440C). The fracture morphologies of the tensile samples were observed by the field emission scanning electron microscopy (FSEM, Sirion 200). The distribution of the above-mentioned precipitated phases in the Al-Zn-Mg-Cu alloy was observed by transmission electron microscope (TEM, Tecnai G2 20) and the corresponding phase compositions were evaluated by the energy dispersive spectroscopy (EDS).', 'The tensile strengths of the above-mentioned alloys were tested by the tensile testing machine (Shimadzu AG-IC100 kN) in a drawing speed of 1.0\u202fmm\u202fmin−1. The corresponding Vickers hardness of the above-mentioned alloys was examined via the micro hardness tester (Wilson 430SVD) at 4.9\u202fN for the duration of 15\u202fs. Their thermal analysis was carried out in the differential scanning calorimeter (DSC, STA449F3). Specifically, the samples were sealed in the Al pans and heated in a flowing argon atmosphere at a constant heating speed of 10\u202f°C min−1. Electrical conductivity was measured by the digital micrometer (MCP-T700) with PSP1512129B gold probes. Each plane of the measurements was tested for 3 times and their average values were calculated.'], 'name': 'Microstructure characterizations and property tests', 'type': 'ce_section'}], 'name': 'Experimental procedures', 'type': 'ce_section'}, {'content': [{'content': ['The Ti microparticles are utilized to improve the wettability between TiN nanoparticles and aluminum liquids, and the composite refiner is named as TiN/Ti refiner []. As shown in Fig.\xa01 , the ball-milled TiN nanoparticles were well-dispersed and supported onto the surfaces of the Ti microparticles.', 'The lab-made Al-Zn-Mg-Cu alloys (Al-7.0Zn-2.5Mg-2.5Cu, in the mass ratio) were synthesized in the graphite crucible of the resistance heated furnace via melting commercially available high-purity Al, Zn, Mg and Cu by the above-mentioned mass ratio. The appropriate amount of TiN/Ti refiner was stirred into the Al-Zn-Mg-Cu melts at the temperature of 730\u202f°C and held the temperature for 10\u202fmin. Then the corresponding mel ...
# Processed and saved: Data/ExperimentalMethod/10.1016-j.jallcom.2018.02.271.json
# Data/TextJSON/10.1007-s00170-019-04167-2.json
# filterd: [{'name': 'Experiment of SPIF', 'content': ['To perform SPIF process, the initial square blanks with the dimensions of 100\xa0mm\u2009×\u2009100\xa0mm were cut from the employed sheet. In the present research, SPIF of a truncated pyramid with the major base of 58\xa0mm\u2009×\u200958\xa0mm and different wall angles is considered. A hemispherical head forming tool made from cold working tool steel with the diameter of 10\xa0mm, a spiral tool path with the vertical pitch of 1\xa0mm, and a feed rate of 1260\xa0mm/min without spindle rotation were considered to carry out SPIF process. To reduce friction between the sheet and the forming tool, hydraulic oil was utilized as a lubricant. A backing plate with a hole in the form of the periphery of the desired shape is usually used in SPIF to decrease the sheet bending near the part base. Here, a backing plate with a square hole of 60\xa0mm\u2009×\u200960\xa0mm dimensions was implemented. The employed equipment of SPIF process which is mounted on a three-axis CNC milling machine is shown in Fig. 1.']}, {'name': 'Heat treatment cycle', 'content': ['The aim of implementing the cycle I (Fig.\xa02a) is performing the forming process before the precipitation hardening in which the sheet metal still has an appropriate formability. To this end, in the cycle I, the effect of the solution time and temperature on the formability and the hardness after aging is studied at the three temperatures of 530\xa0°C, 545\xa0°C, and 560\xa0°C and for the three holding time of 30\xa0min, 75\xa0min, and 120\xa0min. The upper level for the solution temperature was selected as 560\xa0°C with respect to the solidus point of the considered alloy which is equal to 580\xa0°C . Based on the frequently used solution temperature suggested in , the lowest solution temperature was chosen to be 530\xa0°C. In the cycle I, the formed sheet in the supersaturated solid solution state is artificially aged at 180\xa0°C for 6\xa0h and naturally aged at room temperature for 14\xa0days. Since the microstructure of the AA6061 sheet in the supersaturated state is highly unstable at the room temperature, the hardness test after the SPIF process and before the aging treatment is avoided to eliminate the effect of the preparation and hardness testing duration on results.']}, {'name': 'The heat treatment cycle I', 'content': ['As schematically shown in Fig. 2a, at the beginning of the cycle I, the solution treatment is carried out at the times and temperatures described in Section 2.3. According to Fig. 2a, the hardness is measured before the SPIF process. Figure 6 illustrates the hardness obtained after the solution treatment under different conditions. After 30\xa0min of the solution treatment at all the investigated temperatures, the hardness significantly decreases due to homogenization and recovery. With the dissolution of the secondary phase in the matrix and by the annihilation of dislocations generated during the previous rolling process, the hardness of the sheet is considerably reduced from the initial value of 108.9 HV0.1. As explained in Section 3.5.3, by increasing the solution time, the size, volume, and type of precipitates available in matrix are altered and consequently the hardness is changed. The increasing trend of the hardness until the solution time of 75\xa0min can be due to the recrystallization phenomenon. During the recrystallization phenomenon, new grains nucleate at old grain boundaries and the density of the grain boundaries increases. As a result, the hardness is improved compared to the solution time of 30\xa0min, but is still significantly lower than the hardness of the as-received sheet. By increasing the solution time from 75\xa0min to 120\xa0min, different hardness behaviors can be observed at investigated solution temperatures. At the solution temperature of 560\xa0°C, the volume of Mg2Si particles decreases and Si-rich precipitates grow. So, the hardness is reduced at this temperature for  ...
# Processed and saved: Data/ExperimentalMethod/10.1007-s00170-019-04167-2.json
#
# Processing complete. Files processed: 5

# %% [markdown]
# ## 4.1.2 Pre-Extracting by prompt engineering

# %%
import csv
import os
import json
from platform import system
import time
import chardet
from tqdm import tqdm
import openai
from openai import OpenAI
from utils import *


# -- global var start --
api_key = "..." ### Fill in API_key
base_url = "..." ### Fill in base_url
input_csv = r'Prompt+Example/Example/OneShot-Table.csv'  # CSV file path containing 'Input' and 'Output' columns
input_data_path = r'Data/Table-Combined'  # Directory containing new input data
output_path = r'Data/Table-Combine'  # Directory to save the results
n_folder_path = r'Data/Table-Combine'  # Folder to store files without 'Table' in the name
system_content = """ ###### """ # Fill in your prompt
system_instructions = {
    "role": "system",
    "content": system_content
}

client = OpenAI(
    api_key=api_key,
    base_url=base_url
)
# -- global var end --


# -- functions start --
# 1. create user content
def create_user_content():
    # Read the CSV file containing I/O pairs
    example_content = ''' ### ''' # Fill in your prompt
    with open(input_csv, mode='r') as file:
        csv_reader = csv.DictReader(file)
        # Collecting I/O pairs from CSV
        example_num = 11
        for row in csv_reader:
            ex1 = row["Input"],
            ex1_output = row["Output"],
            example_content += f"""### Example {example_num}:\nInput:\n{ex1}\nOutput:\n{ex1_output}\n"""
            example_num += 1
    return example_content


# 2. detect_file_encoding
def detect_file_encoding(file_path):
    with open(file_path, 'rb') as f:
        raw_data = f.read()
        result = chardet.detect(raw_data)
        return result['encoding']
# 3 .get root dirs
def get_dirs(root_dir):
    dirs = os.listdir(root_dir)
    if '.DS_Store' in dirs:
        dirs.remove('.DS_Store')
    return dirs

# 4. detect_file_exist
def detect_file_exist(file_path):
    if os.path.exists(file_path):
        return True
    else:
        return False

# -- functions end --
def few_shot_from_csv(input_csv, input_data_path, output_path, api_key, n_folder_path):
    # Process new input data and get prediction
    file_list = os.listdir(input_data_path)  # Load input data
    flag = 1
    for file in file_list:
        print(f"current file: {file},index:{flag}")
        if detect_file_exist(os.path.join(output_path,file)):
            print(f" {os.path.join(output_path,file)} Exist")
            continue
        messages = [system_instructions]  # Add system instruction first
        user_instructions = {
            "role": "user",
            "content": create_user_content()
        }
        messages.append(user_instructions)

        # Maintain original file names
        input_file_path = os.path.join(input_data_path, file)
        output_file_name = os.path.splitext(file)[0] + '.json'
        output_file_path = os.path.join(output_path, output_file_name)
        encodeing = detect_file_encoding(input_file_path)
        # Read file content
        with open(input_file_path, 'r', encoding=encodeing, errors='ignore') as input_file:
            text = input_file.read()
            # print(text)
        print(f"Processing file: {file}")

        # Add the new input to be processed by the model
        messages.append({"role": "user", "content": text})
        print(f"submited {file}")
        response = client.chat.completions.create(
            model="gpt-4-1106-preview",
            messages=messages,
            temperature=0.3,
        #    frequency_penalty=0,
        #    presence_penalty=0
        #    max_completion_tokens = 8192
        )

        prediction = response.choices[0].message.content.strip()
        print(f"predicted {prediction}")
        send_num = 1
        max_retries = 3
        retries = 0
        while True:

            if "..." in prediction:
                send_num += 1
                print(f"Omit,ask again : {send_num}")
                if send_num >= 3:
                    messages = messages[0:-3]
                messages.append({"role": "assistant", "content": prediction})
                messages.append({"role": "user",
                                 "content": "Do not omit and Continue your output, each cell should be converted !!!"})

                if retries < max_retries:
                    try:
                        response = client.chat.completions.create(
                            model="gpt-4-1106-preview",
                            messages=messages,
                            temperature=0.3,
                        #    frequency_penalty=0,
                        #    presence_penalty=0,
                        #    max_completion_tokens = 8192
                        )
                        prediction = response.choices[0].message.content.strip()

                    except openai.InternalServerError as e:
                        retries += 1
                        print(f"Omit：{e}。Retrying... ({retries}/{max_retries})")
                        time.sleep(2 ** retries)  # 指数回退延迟
                        if retries == max_retries:
                            raise Exception("Maximized Retry times. Overloaded")
            else:
                # print("omit not in prediction,ask again")
                # print("：Complete，Save it")
                break
        # print(prediction)
        if not os.path.exists(output_path):
            print(output_path)
            os.mkdir(output_path)
        with open(os.path.join(output_path,file), "w") as f:
            f.write(prediction)
        print("：Completed，Save it as:", output_path + file)

def main():
    """
    Main function to set up parameters, read configuration, and invoke the few-shot learning process.
    """
       # Ensure output and 'N' paths exist
    if not os.path.exists(output_path):
        os.makedirs(output_path)

    if not os.path.exists(n_folder_path):
        os.makedirs(n_folder_path)

    input_json_dirs = get_dirs(input_data_path)
    print("input_json_dirs:",input_json_dirs)
    for input_dir in input_json_dirs:
        print("input_dir:",input_dir)
        input_json_path = os.path.join(input_data_path, input_dir)
        output_json_path = os.path.join(output_path, input_dir)
        few_shot_from_csv(input_csv, input_json_path, output_json_path, api_key, n_folder_path)

    # Call the few-shot function to process the CSV and input data
    #few_shot_from_csv(input_csv, input_data_path, output_path, api_key, n_folder_path)

# Run the main function if this script is executed
if __name__ == "__main__":
    main()
# Out:
# input_json_dirs: ['1']
# input_dir: 1
# current file: 10.1016-j.msea.2018.12.103.json,index:1
# Processing file: 10.1016-j.msea.2018.12.103.json
# submited 10.1016-j.msea.2018.12.103.json
# predicted JSON for Initial material:
# {
#   "Scan step size, μm": "0.25",
#   "Map area, μm^2": "400 × 400",
#   "Number of pixels": "2,957,724",
#   "Number of grains": "614",
#   "Yield strength, MPa": "136 ± 1.0",
#   "Ultimate tensile strength, MPa": "349 ± 2.0",
#   "Ductility, %": "28 ± 1.0"
# }
#
# JSON for 30 pct. rolling:
# {
#   "Scan step size, μm": "0.7",
#   "Map area, μm^2": "400 × 400",
#   "Number of pixels": "589,463",
#   "Number of grains": "2514"
# }
#
# JSON for 40 pct. rolling:
# {
#   "Scan step size, μm": "0.25",
#   "Map area, μm^2": "300 × 300",
#   "Number of pixels": "1,661,683",
#   "Number of grains": "6532",
#   "Yield strength, MPa": "431 ± 0.6",
#   "Ultimate tensile strength, MPa": "478 ± 0.6",
#   "Ductility, %": "7.5 ± 0.2",
#   "Measured yield strength, MPa": "431",
#   "Threshold stress, MPa": "110",
#   "Calculated dislocation strengthening, MPa": "214",
#   "Predicted LAB strengthening, MPa": "107"
# }
#
# JSON for 60 pct. rolling:
# {
#   "Scan step size, μm": ["0.7", "0.25"],
#   "Map area, μm^2": ["400 × 400", "200 × 250"],
#   "Number of pixels": ["589,463", "924,578"],
#   "Number of grains": ["3089", "2379"],
#   "Yield strength, MPa": "462 ± 5.1",
#   "Ultimate tensile strength, MPa": "502 ± 3.8",
#   "Ductility, %": "6.5 ± 0.3",
#   "Measured yield strength, MPa": "462",
#   "Threshold stress, MPa": "110",
#   "Calculated dislocation strengthening, MPa": "226",
#   "Predicted LAB strengthening, MPa": "126"
# }
#
# JSON for 80 pct. rolling:
# {
#   "Scan step size, μm": "0.25",
#   "Map area, μm^2": "200 × 250",
#   "Number of pixels": "924,578",
#   "Number of grains": "4679",
#   "Yield strength, MPa": "521 ± 1.3",
#   "Ultimate tensile strength, MPa": "553 ± 0.4",
#   "Ductility, %": "4.5 ± 0.2",
#   "Measured yield strength, MPa": "521",
#   "Threshold stress, MPa": "110",
#   "Calculated dislocation strengthening, MPa": "271",
#   "Predicted LAB strengthening, MPa": "140"
# }
# Data/Table-Combine/1
# ：Completed，Save it as: Data/Table-Combine/110.1016-j.msea.2018.12.103.json
# current file: 10.1007-s11665-019-04152-6.json,index:1
# Processing file: 10.1007-s11665-019-04152-6.json
# submited 10.1007-s11665-019-04152-6.json
# predicted JSON for Samples As-solution extrusion:
# {
#   "Tension": {
#     "YS (MPa)": "243 ± 3",
#     "PS (MPa)": "350 ± 4",
#     "UP (%)": "6.6 ± 0.5"
#   },
#   "Compression": {
#     "YS (MPa)": "143 ± 2",
#     "PS (MPa)": "433 ± 3",
#     "UP (%)": "18.6 ± 0.3"
#   }
# }
#
# JSON for Samples Direct aging:
# {
#   "Tension": {
#     "YS (MPa)": "276 ± 5",
#     "PS (MPa)": "391 ± 6",
#     "UP (%)": "4.1 ± 0.6"
#   },
#   "Compression": {
#     "YS (MPa)": "230 ± 1",
#     "PS (MPa)": "514 ± 3",
#     "UP (%)": "11.0 ± 0.2"
#   }
# }
#
# JSON for Samples Unidirectional torsion and then aging:
# {
#   "Tension": {
#     "YS (MPa)": "272 ± 4",
#     "PS (MPa)": "361 ± 5",
#     "UP (%)": "2.6 ± 0.8"
#   },
#   "Compression": {
#     "YS (MPa)": "252 ± 1",
#     "PS (MPa)": "506 ± 4",
#     "UP (%)": "12.8 ± 0.3"
#   }
# }
#
# JSON for Samples Reciprocating torsion and then aging:
# {
#   "Tension": {
#     "YS (MPa)": "308 ± 6",
#     "PS (MPa)": "457 ± 3",
#     "UP (%)": "3.5 ± 0.6"
#   },
#   "Compression": {
#     "YS (MPa)": "256 ± 2",
#     "PS (MPa)": "550 ± 3",
#     "UP (%)": "11.3 ± 0.3"
#   }
# }
# ：Completed，Save it as: Data/Table-Combine/110.1007-s11665-019-04152-6.json
# current file: 10.1007-s11665-018-3478-4.json,index:1
# Processing file: 10.1007-s11665-018-3478-4.json
# submited 10.1007-s11665-018-3478-4.json
# predicted Structured format for Analysis of Fe-Mn rosette particles 1:
# - Al (wt%): 59.1
# - Si (wt%): 9.2
# - Cr (wt%): 4.3
# - Mn (wt%): 6.9
# - Fe (wt%): 19.7
# - Cu (wt%): 0.8
#
# Structured format for Analysis of Fe-Mn rosette particles 2:
# - Al (wt%): 58.3
# - Si (wt%): 9.2
# - Cr (wt%): 4.5
# - Mn (wt%): 6.9
# - Fe (wt%): 20.2
# - Cu (wt%): 0.9
#
# Structured format for Analysis of Fe-Mn rosette particles 3:
# - Al (wt%): 59.5
# - Si (wt%): 10.6
# - Cr (wt%): 3.7
# - Mn (wt%): 6.4
# - Fe (wt%): 18.9
# - Cu (wt%): 1.1
#
# Structured format for Analysis of Fe-Mn rosette particles 4:
# - Al (wt%): 67.5
# - Si (wt%): 10.2
# - Cr (wt%): 2.3
# - Mn (wt%): 4.7
# - Fe (wt%): 13.4
# - Cu (wt%): 1.9
#
# Structured format for Analysis of Fe-Mn rosette particles 5:
# - Al (wt%): 58.7
# - Si (wt%): 9.6
# - Cr (wt%): 4.1
# - Mn (wt%): 6.8
# - Fe (wt%): 19.8
# - Cu (wt%): 1.0
#
# Structured format for Analysis of Fe-Mn rosette particles 6:
# - Al (wt%): 59.0
# - Si (wt%): 10.3
# - Cr (wt%): 3.3
# - Mn (wt%): 6.6
# - Fe (wt%): 19.5
# - Cu (wt%): 1.4
#
# Structured format for Analysis of Fe-Mn rosette particles 7:
# - Al (wt%): 64.3
# - Si (wt%): 12.0
# - Cr (wt%): 2.9
# - Mn (wt%): 4.8
# - Fe (wt%): 14.8
# - Cu (wt%): 1.3
#
# Structured format for Analysis of Fe-Mn rosette particles 8:
# - Al (wt%): 58.2
# - Si (wt%): 9.8
# - Cr (wt%): 3.0
# - Mn (wt%): 6.4
# - Fe (wt%): 20.1
# - Cu (wt%): 2.5
#
# Structured format for Analysis of Fe-Mn rosette particles 9:
# - Al (wt%): 59.0
# - Si (wt%): 8.9
# - Cr (wt%): 3.8
# - Mn (wt%): 6.7
# - Fe (wt%): 19.9
# - Cu (wt%): 1.7
#
# Structured format for Analysis of Fe-Mn rosette particles 10:
# - Al (wt%): 61.1
# - Si (wt%): 11.1
# - Cr (wt%): 3.6
# - Mn (wt%): 5.9
# - Fe (wt%): 17.5
# - Cu (wt%): 0.9
#
# Structured format for Analysis of Fe-Mn rosette particles 11:
# - Al (wt%): 59.0
# - Si (wt%): 9.4
# - Cr (wt%): 4.0
# - Mn (wt%): 6.8
# - Fe (wt%): 19.9
# - Cu (wt%): 0.9
# ：Completed，Save it as: Data/Table-Combine/110.1007-s11665-018-3478-4.json
# current file: 10.1039-b811775f.json,index:1
# Processing file: 10.1039-b811775f.json
# submited 10.1039-b811775f.json
# predicted Structured information for each alloy sample:
#
# JSON for Sample Ru22Cu7:
# ```json
# {
#   "Ru/Cu (SRu3p3/2× 2.48)/SCu2p3/2": {
#     "[Surface = bulk]": "3.14",
#     "As-leached": "2.63",
#     "Annealed (T/°C)": "2.03 (200)"
#   },
#   "EXAFS fitting data at the Cu K-edge": {
#     "As-leached": {
#       "Cu–O": {
#         "N1": "3.2",
#         "R1": "1.92",
#         "σ21": "0.0064"
#       },
#       "Cu–Cu": {
#         "N2": "2.5",
#         "R2": "2.55",
#         "σ22": "0.0200"
#       },
#       "Cu–Ru": {
#         "N3": "3.9",
#         "R3": "2.65",
#         "σ23": "0.013"
#       },
#       "Relative ratio": {
#         "Cu–O": "58",
#         "Cu–Cu": "12",
#         "Cu–Ru": "30"
#       }
#     },
#     "Annealed 200 °C": {
#       "Cu–O": {
#         "N1": "2.9",
#         "R1": "1.89",
#         "σ21": "0.0083"
#       },
#       "Cu–Cu": {
#         "N2": "7.4",
#         "R2": "2.55",
#         "σ22": "0.0200"
#       },
#       "Cu–Ru": {
#         "N3": "4.2",
#         "R3": "2.65",
#         "σ23": "0.011"
#       },
#       "Relative ratio": {
#         "Cu–O": "23",
#         "Cu–Cu": "34",
#         "Cu–Ru": "43"
#       }
#     },
#     "Annealed 250 °C": {
#       "Cu–O": {
#         "N1": "2.8",
#         "R1": "1.89",
#         "σ21": "0.0073"
#       },
#       "Cu–Cu": {
#         "N2": "8.2",
#         "R2": "2.55",
#         "σ22": "0.0200"
#       },
#       "Cu–Ru": {
#         "N3": "4.2",
#         "R3": "2.65",
#         "σ23": "0.008"
#       },
#       "Relative ratio": {
#         "Cu–O": "25",
#         "Cu–Cu": "29",
#         "Cu–Ru": "45"
#       }
#     },
#     "Annealed 300 °C": {
#       "Cu–O": {
#         "N1": "1.6",
#         "R1": "1.87",
#         "σ21": "0.0023"
#       },
#       "Cu–Cu": {
#         "N2": "7.7",
#         "R2": "2.55",
#         "σ22": "0.0200"
#       },
#       "Cu–Ru": {
#         "N3": "4.2",
#         "R3": "2.65",
#         "σ23": "0.010"
#       },
#       "Relative ratio": {
#         "Cu–O": "20",
#         "Cu–Cu": "35",
#         "Cu–Ru": "44"
#       }
#     },
#     "Annealed 350 °C": {
#       "Cu–O": {
#         "N1": "1.4",
#         "R1": "1.80",
#         "σ21": "0.0037"
#       },
#       "Cu–Cu": {
#         "N2": "9.3",
#         "R2": "2.55",
#         "σ22": "0.0200"
#       },
#       "Cu–Ru": {
#         "N3": "3.1",
#         "R3": "2.65",
#         "σ23": "N/A"
#       },
#       "Relative ratio": {
#         "Cu–O": "N/A",
#         "Cu–Cu": "N/A",
#         "Cu–Ru": "N/A"
#       }
#     }
#   },
#   "CO oxidation activity": {
#     "40 °C": "2",
#     "55 °C": "8",
#     "75 °C": "40 (4)",
#     "100 °C": "85 (6)",
#     "120 °C": "100 (9)",
#     "Tloa /°C": "64"
#   }
# }
# ```
#
# JSON for Sample Ru17Cu12.5:
# ```json
# {
#   "Ru/Cu (SRu3p3/2× 2.48)/SCu2p3/2": {
#     "[Surface = bulk]": "1.36",
#     "As-leached": "1.67",
#     "Annealed (T/°C)": "0.85 (300)"
#   },
#   "EXAFS fitting data at the Cu K-edge": {
#     "As-leached": {
#       "Cu–O": {
#         "N1": "3.0",
#         "R1": "1.89",
#         "σ21": "0.0079"
#       },
#       "Cu–Cu": {
#         "N2": "4.7",
#         "R2": "2.51",
#         "σ22": "0.0083"
#       },
#       "Cu–Ru": {
#         "N3": "N/A",
#         "R3": "N/A",
#         "σ23": "N/A"
#       },
#       "Relative ratio": {
#         "Cu–O": "35",
#         "Cu–Cu": "65",
#         "Cu–Ru": "N/A"
#       }
#     },
#     "Annealed 250 °C": {
#       "Cu–O": {
#         "N1": "2.2",
#         "R1": "2.02",
#         "σ21": "0.0158"
#       },
#       "Cu–Cu": {
#         "N2": "8.5",
#         "R2": "2.51",
#         "σ22": "0.0075"
#       },
#       "Cu–Ru": {
#         "N3": "N/A",
#         "R3": "N/A",
#         "σ23": "N/A"
#       },
#       "Relative ratio": {
#         "Cu–O": "16",
#         "Cu–Cu": "84",
#         "Cu–Ru": "N/A"
#       }
#     },
#     "Annealed 300 °C": {
#       "Cu–O": {
#         "N1": "1.9",
#         "R1": "2.04",
#         "σ21": "0.0010"
#       },
#       "Cu–Cu": {
#         "N2": "8.1",
#         "R2": "2.51",
#         "σ22": "0.0076"
#       },
#       "Cu–Ru": {
#         "N3": "N/A",
#         "R3": "N/A",
#         "σ23": "N/A"
#       },
#       "Relative ratio": {
#         "Cu–O": "14",
#         "Cu–Cu": "86",
#         "Cu–Ru": "N/A"
#       }
#     }
#   },
#   "CO oxidation activity": {
#     "40 °C": "2.5",
#     "55 °C": "10",
#     "75 °C": "35 (10)",
#     "100 °C": "85 (16)",
#     "120 °C": "100 (30)",
#     "Tloa /°C": "70"
#   }
# }
# ```
#
# JSON for Sample Ru10Cu20:
# ```json
# {
#   "Ru/Cu (SRu3p3/2× 2.48)/SCu2p3/2": {
#     "[Surface = bulk]": "0.50",
#     "As-leached": "0.13",
#     "Annealed (T/°C)": "0.02 (300)"
#   },
#   "EXAFS fitting data at the Cu K-edge": {
#     "As-leached": {
#       "Cu–O": {
#         "N1": "4.1",
#         "R1": "1.92",
#         "σ21": "0.0066"
#       },
#       "Cu–Cu": {
#         "N2": "5.5",
#         "R2": "2.54",
#         "σ22": "0.0098"
#       },
#       "Cu–Ru": {
#         "N3": "N/A",
#         "R3": "N/A",
#         "σ23": "N/A"
#       },
#       "Relative ratio": {
#         "Cu–O": "41",
#         "Cu–Cu": "59",
#         "Cu–Ru": "N/A"
#       }
#     },
#     "Annealed 250 °C": {
#       "Cu–O": {
#         "N1": "2.2",
#         "R1": "1.93",
#         "σ21": "0.0077"
#       },
#       "Cu–Cu": {
#         "N2": "7.1",
#         "R2": "2.53",
#         "σ22": "0.0089"
#       },
#       "Cu–Ru": {
#         "N3": "N/A",
#         "R3": "N/A",
#         "σ23": "N/A"
#       },
#       "Relative ratio": {
#         "Cu–O": "15",
#         "Cu–Cu": "85",
#         "Cu–Ru": "N/A"
#       }
#     },
#     "Annealed 300 °C": {
#       "Cu–O": {
#         "N1": "2.0",
#         "R1": "1.94",
#         "σ21": "0.0081"
#       },
#       "Cu–Cu": {
#         "N2": "6.9",
#         "R2": "2.53",
#         "σ22": "0.0089"
#       },
#       "Cu–Ru": {
#         "N3": "N/A",
#         "R3": "N/A",
#         "σ23": "N/A"
#       },
#       "Relative ratio": {
#         "Cu–O": "12",
#         "Cu–Cu": "88",
#         "Cu–Ru": "N/A"
#       }
#     }
#   },
#   "CO oxidation activity": {
#     "40 °C": "1.5",
#     "55 °C": "8",
#     "75 °C": "38 (12)",
#     "100 °C": "80 (20)",
#     "120 °C": "90 (35)",
#     "Tloa /°C": "72"
#   }
# }
# ```
#
# Please note that some information was not provided in the original data and is marked as "N/A".
# ：Completed，Save it as: Data/Table-Combine/110.1039-b811775f.json
# current file: 10.1016-j.jallcom.2018.02.271.json,index:1
# Processing file: 10.1016-j.jallcom.2018.02.271.json
# submited 10.1016-j.jallcom.2018.02.271.json
# predicted JSON for Al-Zn-Mg-Cu alloy with No refiner:
# {
#   "Precipitates": {
#     "G.P.": {
#       "Peak temperature/T p , °C": "83.4",
#       "Activation energy/E a , kJ/mol": "154.1"
#     },
#     "η′": {
#       "Peak temperature/T p , °C": "191.4",
#       "Activation energy/E a , kJ/mol": "106.8"
#     },
#     "η": {
#       "Peak temperature/T p , °C": "235.6",
#       "Activation energy/E a , kJ/mol": "94.9"
#     }
#   }
# }
#
# JSON for Al-Zn-Mg-Cu alloy with Ti refiner:
# {
#   "Precipitates": {
#     "G.P.": {
#       "Peak temperature/T p , °C": "86.1",
#       "Activation energy/E a , kJ/mol": "152.2"
#     },
#     "η′": {
#       "Peak temperature/T p , °C": "187.4",
#       "Activation energy/E a , kJ/mol": "108.1"
#     },
#     "η": {
#       "Peak temperature/T p , °C": "233.1",
#       "Activation energy/E a , kJ/mol": "95.6"
#     }
#   }
# }
#
# JSON for Al-Zn-Mg-Cu alloy with TiN/Ti refiner:
# {
#   "Precipitates": {
#     "G.P.": {
#       "Peak temperature/T p , °C": "93.5",
#       "Activation energy/E a , kJ/mol": "147.5"
#     },
#     "η′": {
#       "Peak temperature/T p , °C": "185.2",
#       "Activation energy/E a , kJ/mol": "108.7"
#     },
#     "η": {
#       "Peak temperature/T p , °C": "232.9",
#       "Activation energy/E a , kJ/mol": "95.7"
#     }
#   }
# }
# ：Completed，Save it as: Data/Table-Combine/110.1016-j.jallcom.2018.02.271.json
# current file: 10.1016-j.jallcom.2012.07.110.json,index:1
# Processing file: 10.1016-j.jallcom.2012.07.110.json
# submited 10.1016-j.jallcom.2012.07.110.json
# predicted Structured format for Spec. 2:
# - Pre-com. (%): 0 (Compressibility), 0 (Recovery)
# - Temp. (K): 523 (Compressibility), 523 (Recovery)
# - Time (min): 60 (Compressibility), 60 (Recovery)
# - Com. (%): 2.7 (Compressibility)
# - Rec. (%): 95.4 (Recovery)
#
# Structured format for Spec. 3:
# - Pre-com. (%): 0 (Compressibility), 0 (Recovery)
# - Temp. (K): 673 (Compressibility), 673 (Recovery)
# - Time (min): 120 (Compressibility), 120 (Recovery)
# - Com. (%): 3 (Compressibility)
# - Rec. (%): 73.9 (Recovery)
#
# Structured format for Spec. 4:
# - Pre-com. (%): 0 (Compressibility), 0 (Recovery)
# - Temp. (K): 823 (Compressibility), 823 (Recovery)
# - Time (min): 180 (Compressibility), 180 (Recovery)
# - Com. (%): 2.8 (Compressibility)
# - Rec. (%): 85.7 (Recovery)
#
# Structured format for Spec. 5:
# - Pre-com. (%): 0.20 (Compressibility), 0.20 (Recovery)
# - Temp. (K): 523 (Compressibility), 523 (Recovery)
# - Time (min): 180 (Compressibility), 180 (Recovery)
# - Com. (%): 3.4 (Compressibility)
# - Rec. (%): 91.9 (Recovery)
#
# Structured format for Spec. 6:
# - Pre-com. (%): 0.20 (Compressibility), 0.20 (Recovery)
# - Temp. (K): 673 (Compressibility), 673 (Recovery)
# - Time (min): 60 (Compressibility), 60 (Recovery)
# - Com. (%): 4 (Compressibility)
# - Rec. (%): 86.5 (Recovery)
#
# Structured format for Spec. 7:
# - Pre-com. (%): 0.20 (Compressibility), 0.20 (Recovery)
# - Temp. (K): 823 (Compressibility), 823 (Recovery)
# - Time (min): 120 (Compressibility), 120 (Recovery)
# - Com. (%): 4.9 (Compressibility)
# - Rec. (%): 85.7 (Recovery)
#
# Structured format for Spec. 8:
# - Pre-com. (%): 0.70 (Compressibility), 0.70 (Recovery)
# - Temp. (K): 523 (Compressibility), 523 (Recovery)
# - Time (min): 120 (Compressibility), 120 (Recovery)
# - Com. (%): 2.7 (Compressibility)
# - Rec. (%): 91 (Recovery)
#
# Structured format for Spec. 9:
# - Pre-com. (%): 0.70 (Compressibility), 0.70 (Recovery)
# - Temp. (K): 673 (Compressibility), 673 (Recovery)
# - Time (min): 180 (Compressibility), 180 (Recovery)
# - Com. (%): 3.9 (Compressibility)
# - Rec. (%): 72.1 (Recovery)
#
# Structured format for Spec. 10:
# - Pre-com. (%): 0.70 (Compressibility), 0.70 (Recovery)
# - Temp. (K): 823 (Compressibility), 823 (Recovery)
# - Time (min): 60 (Compressibility), 60 (Recovery)
# - Com. (%): 3.4 (Compressibility)
# - Rec. (%): 89.4 (Recovery)
#
# Structured format for Spec. k1:
# - Pre-com. (%): 2.83 (Compressibility), 85.00 (Recovery)
# - Temp. (K): 2.93 (Compressibility), 92.77 (Recovery)
# - Time (min): 3.37 (Compressibility), 90.43 (Recovery)
#
# Structured format for Spec. k2:
# - Pre-com. (%): 4.10 (Compressibility), 88.03 (Recovery)
# - Temp. (K): 3.63 (Compressibility), 77.50 (Recovery)
# - Time (min): 3.53 (Compressibility), 83.53 (Recovery)
#
# Structured format for Spec. k3:
# - Pre-com. (%): 3.33 (Compressibility), 84.17 (Recovery)
# - Temp. (K): 3.70 (Compressibility), 86.93 (Recovery)
# - Time (min): 3.37 (Compressibility), 83.23 (Recovery)
#
# Structured format for Spec. Range:
# - Pre-com. (%): 1.27 (Compressibility), 3.87 (Recovery)
# - Temp. (K): 0.77 (Compressibility), 15.27 (Recovery)
# - Time (min): 0.17 (Compressibility), N/A (Recovery)
# ：Completed，Save it as: Data/Table-Combine/110.1016-j.jallcom.2012.07.110.json
# current file: 10.1016-j.energy.2017.03.162.json,index:1
# Processing file: 10.1016-j.energy.2017.03.162.json
# submited 10.1016-j.energy.2017.03.162.json
# predicted JSON for Catalyst Pt/C:
# {
#   "j at 0.6V (mA/cm2)": "336.8",
#   "-b (mV/Dec)": "47.0",
#   "j 0 (mA/cm2)": "1.59×10−6",
#   "R (Ω-cm2)": "0.6270",
#   "m (mV)": "1.4",
#   "n (cm2/mA)": "0.0065",
#   "R 2": "0.9990",
#   "E corr (mV)": "−224",
#   "b a (mV/dec)": "286",
#   "b c (mV/dec)": "262",
#   "j corr (mA/cm2)": "9.91",
#   "ESA loss at 500th cycle (%)": "73.6"
# }
#
# JSON for Catalyst PtCr/C:
# {
#   "j at 0.6V (mA/cm2)": "358.8",
#   "-b (mV/Dec)": "55.0",
#   "j 0 (mA/cm2)": "1.20×10−5",
#   "R (Ω-cm2)": "0.4500",
#   "m (mV)": "5.4",
#   "n (cm2/mA)": "0.0053",
#   "R 2": "0.9991",
#   "E corr (mV)": "−153",
#   "b a (mV/dec)": "183",
#   "b c (mV/dec)": "152",
#   "j corr (mA/cm2)": "2.25",
#   "ESA loss at 500th cycle (%)": "43.6"
# }
#
# JSON for Catalyst PtPd/C:
# {
#   "j at 0.6V (mA/cm2)": "389.2",
#   "-b (mV/Dec)": "59.6",
#   "j 0 (mA/cm2)": "3.49×10−5",
#   "R (Ω-cm2)": "0.3549",
#   "m (mV)": "6.9",
#   "n (cm2/mA)": "0.0051",
#   "R 2": "0.9991",
#   "E corr (mV)": "−195",
#   "b a (mV/dec)": "434",
#   "b c (mV/dec)": "258",
#   "j corr (mA/cm2)": "6.51",
#   "ESA loss at 500th cycle (%)": "60.0"
# }
#
# JSON for Catalyst PtCo/C:
# {
#   "j at 0.6V (mA/cm2)": "392.8",
#   "-b (mV/Dec)": "59.4",
#   "j 0 (mA/cm2)": "3.68×10−5",
#   "R (Ω-cm2)": "0.4047",
#   "m (mV)": "2.7",
#   "n (cm2/mA)": "0.0061",
#   "R 2": "0.9989",
#   "E corr (mV)": "−199",
#   "b a (mV/dec)": "147",
#   "b c (mV/dec)": "107",
#   "j corr (mA/cm2)": "2.84",
#   "ESA loss at 500th cycle (%)": "58.7"
# }
#
# JSON for Catalyst H-PtCr/C:
# {
#   "j at 0.6V (mA/cm2)": "368.4",
#   "-b (mV/Dec)": "51.0",
#   "j 0 (mA/cm2)": "7.74×10−6",
#   "R (Ω-cm2)": "0.5100",
#   "m (mV)": "3.9",
#   "n (cm2/mA)": "0.0054",
#   "R 2": "0.9986",
#   "E corr (mV)": "−154",
#   "b a (mV/dec)": "223",
#   "b c (mV/dec)": "195",
#   "j corr (mA/cm2)": "1.74",
#   "ESA loss at 500th cycle (%)": "41.7"
# }
#
# JSON for Catalyst H-PtPd/C:
# {
#   "j at 0.6V (mA/cm2)": "344.8",
#   "-b (mV/Dec)": "50.6",
#   "j 0 (mA/cm2)": "5.98×10−6",
#   "R (Ω-cm2)": "0.5500",
#   "m (mV)": "1.9",
#   "n (cm2/mA)": "0.0064",
#   "R 2": "0.9992",
#   "E corr (mV)": "−192",
#   "b a (mV/dec)": "388",
#   "b c (mV/dec)": "38",
#   "j corr (mA/cm2)": "8.06",
#   "ESA loss at 500th cycle (%)": "76.6"
# }
#
# JSON for Catalyst H-PtCo/C:
# {
#   "j at 0.6V (mA/cm2)": "379.4",
#   "-b (mV/Dec)": "52.0",
#   "j 0 (mA/cm2)": "7.80×10−6",
#   "R (Ω-cm2)": "0.4730",
#   "m (mV)": "1.8",
#   "n (cm2/mA)": "0.0065",
#   "R 2": "0.9988",
#   "E corr (mV)": "−186",
#   "b a (mV/dec)": "159",
#   "b c (mV/dec)": "124",
#   "j corr (mA/cm2)": "2.68",
#   "ESA loss at 500th cycle (%)": "48.6"
# }
# ：Completed，Save it as: Data/Table-Combine/110.1016-j.energy.2017.03.162.json
# current file: 10.1007-s00170-019-04167-2.json,index:1
# Processing file: 10.1007-s00170-019-04167-2.json
# submited 10.1007-s00170-019-04167-2.json
# predicted JSON for AA6061 Aluminum Alloy:
# ```json
# {
#   "Material": "AA6061",
#   "Composition (weight %)": {
#     "Al": "Base",
#     "Si": "0.73",
#     "Fe": "0.33",
#     "Cu": "0.26",
#     "Mn": "0.04",
#     "Mg": "0.88",
#     "Cr": "0.17",
#     "Zn": "0.05",
#     "Ti": "0.02",
#     "Others": "0.02"
#   },
#   "Mechanical Properties": {
#     "Young’s modulus (GPa)": "74.2",
#     "Yield strength (MPa)": "349.2",
#     "Tensile strength (MPa)": "381.1",
#     "Fracture elongation (%)": "6.95"
#   },
#   "Grain Sizes": {
#     "As received": {
#       "Average grain size (µm)": "20.88",
#       "+ 50° SPIF": "17.75",
#       "+ 70° SPIF": "16.20"
#     },
#     "Annealed": {
#       "Average grain size (µm)": "20.40",
#       "+ 70° SPIF": "19.13",
#       "+ 70° SPIF + T6*": "23.14"
#     },
#     "Solution treated": {
#       "Cycle II +T6": "20.48",
#       "Cycle I +T4*": "21.69",
#       "75 min–530 °C": "19.85",
#       "75 min–545 °C": "18.19",
#       "75 min–560 °C": "15.75",
#       "75 min–545 °C+70° SPIF + T6": "19.48"
#     }
#   }
# }
# ```
# ：Completed，Save it as: Data/Table-Combine/110.1007-s00170-019-04167-2.json
