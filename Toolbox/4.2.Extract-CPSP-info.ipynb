# %% [markdown]
# # Step Four: 2. Extract + classify Alloy "CPSP" information

# %% [markdown]
# ## &#9679; "Composition-Processing-Structure-Performance" (CPSP) Information of Alloy
# #### 1. **Letter "C" in "CPSP" (C)**: Alloy Composition, Alloy_Designation, and Alloy_Formula;
# #### 2. **First letter "P" in "CPSP" (P1)**: Processing routes/Heat treatment (Operation actions, Conditions, and Corresponding parameters in each period);
# #### 3. **Letter "S" in "CPSP" (S)**: Structure/Microstructure (Average Grain Size, Structure type(bcc/fcc/hcp), Strengthening Phase, Characteristics Of Precipitation
# #### (Finer/Uniformly), Grain Boundary(High-angle/Small-angle);
# #### 4. **Second letter "P" in "CPSP" (P2)**: Performance/Properties (Mechancial Properties: σb, σs, δ, σbc, σbb, Young’s modulus, shear modulus, poisson’s ratio,
# #### flexural modulus, hardness, reduction of area, conductivity ... Corrosion Properties: Ecorr, Icorr, KISCC, ISSRT ... Fracture Properties: KIC, toughness,
# #### fatigue strength, fracture mode (brittle/ductile) ... Strengthening Mechanism: grain strengthening, dislocation strengthening, precipitation strengthening,
# #### solid–solution strengthening.

# %% [markdown]
# ## &#9679; Extraction and Classification Alloy "CPSP" Inforamtion from Pre-Processed Alloy Corpus in 4.1
# ### (Multiple Publishers: Elsevier, Springer Nature, Royal Soc Chemistry)
# ### **Step 4.2.1 Merge and Clean Relevant Info output in Different directories**:
# #### **Aims**: Merge output in Abstarct, Combined-Tables, Experimental methods, Results and Discussions sections in 4.1 to get the **completed Alloy "CPSP" Info**.
# #### **HOW TO USE**: Replace the input and output directory paths with your own.
# ### **Step 4.2.2 Extract Complete "CPSP" Info by prompt engineering**:
# #### **Aims**: Sort out alloy composition, processing, microstructure and performance of the same sample into a seperatre JSON structure.
# #### **HOW TO USE**: Refer to 4.1.2, and Fill in your own API_key and base_url, and modify the prompts and examples based on your task.
# ### **Step 4.2.3 Convert "CPSP" Info of different alloys into tabular format**:
# #### **Aims**: Convert information in each JSON object from output in 4.2.2 into tabular format.
# #### **HOW TO USE**: Use the code in 4.2.3.

# %% [markdown]
# ## 4.2.1 Merge and Clean

# %%
import os
import re
import chardet

def detect_encoding(file_path):
    # Read the raw data from the file
    with open(file_path, 'rb') as f:
        raw_data = f.read()
    # Detect the encoding of the file using chardet
    result = chardet.detect(raw_data)
    return result['encoding']

def clean_and_merge_json_files(paths, output_path):
    # Get a set of all file names in the given paths that end with '.json'
    all_files = set()
    for path in paths:
        all_files.update(set([f for f in os.listdir(path) if f.endswith('.json')]))

    # Ensure the output directory exists
    os.makedirs(output_path, exist_ok=True)

    for filename in all_files:
        content_list = []
        
        try:
            # Iterate over each path and merge files with the same name
            for path in paths:
                file_path = os.path.join(path, filename)
                
                if os.path.exists(file_path):
                    # Detect the encoding of the file
                    encoding = detect_encoding(file_path)
                    # Open the file with detected encoding
                    with open(file_path, 'r', encoding=encoding, errors='ignore') as f:
                        content = f.read()
                        
                        # Clean the content by removing unwanted characters and normalizing whitespace
                        cleaned_content = re.sub(r"```json|```", "", content).strip()
                        cleaned_content = re.sub(r"\s+", " ", cleaned_content)  # Remove extra whitespace
                        cleaned_content = cleaned_content.replace("\\n", "").replace("\t", " ")
                        print(cleaned_content)
                        
                        # Attempt to convert the cleaned content into a string format, ensuring it's valid JSON
                        # Here it's assumed that cleaned_content is a JSON string or a string close to JSON format
                        content_list.append(cleaned_content)

            # Write the merged content to the output file
            output_file = os.path.join(output_path, filename)
            with open(output_file, 'w', encoding='utf-8') as f:
                # Separate contents with newline characters to ensure each cleaned content is written
                f.write("\n".join(content_list))
            print(f"Processed and saved {filename} to {output_path}")

        except Exception as e:
            print(f"Failed to process {filename}: {e}")

# Example usage
paths = [
    "Data/PaperJson/Abstract",  # Abstract Folder
    "Data/PaperJson/Experimental-Method-Results",  # Experimental Folder
    "Data/CombinedTable/GPT-Processed-CombinedTable",  # Table Folder
    "Data/PaperJson/Results-Discussions-Results"  # Discussions Folder

]
output_path = "Data/PaperJson/JSON-All-Results" # Output Folder
clean_and_merge_json_files(paths, output_path)
# Out:
# { "DOI": "10.1016/j.actamat.2005.02.010", "Journal": "Acta Materialia", "Keywords": [ "Nickel alloy", "Yield strength", "Precipitate free zones", "Transmission electron microscopy", "Computer simulations" ], "Sections": [], "Title": "The effects of a second aging treatment on the yield strength of γ′-hardened NIMONIC PE16-polycrystals having γ′-precipitate free zones", "abstract": "The nickel-base alloy NIMONIC PE16 is strengthened by coherent spherical nano-scale precipitates of the Ll(2)-long range ordered gamma'-phase. Along grain boundaries precipitate free zones (PFZs) may form, which lower the yield strength drastically. In this study it has been attempted to eliminate this softening effect by double aging treatments: the main gamma'-precipitate dispersion is grown at 1079 K and subsequently finer gamma'-particles are precipitated at 949 K - in between the larger 1079 K-gamma'-precipitates and in the PFZs formed at 1079 K. Unfortunately softening by PFZs could not be suppressed by these procedures. In addition, multiple strengthening of finely grained, PFZ-free NIMONIC PE16-polycrystals by gamma'-precipitates, by atoms dissolved in the matrix, and by grain boundaries has been modeled and computer simulated. (c) 2005 Acta Materialia Inc. Published by Elsevier Ltd. All rights reserved." }
# { "Alloy_Designation/Alloy_Formula": "NIMONIC PE16", "γ′-nucleation treatment": "973 K, 2 hours", "Aging": [ { "stage": 1, "temperature": "1079 K", "duration": "51.5 h", "γ′-precipitate dispersion": { "f1": "0.061 ± 0.009", "r1": "25.0 ± 1.5 nm" } }, { "stage": 2, "temperature": "949 K", "duration": "42.5 h", "γ′-precipitate dispersion": { "f1'": "≈0.07", "r1'": "≈26 nm", "f2": "≈0.04", "r2": "≈4 nm" } } ], "Grain Size": [ { "designation": "NO-PFZi", "average spacing of GBs": "6.1 μm" }, { "designation": "PFZi", "average spacing of GBs": "265 μm" } ], "Tensile Test Conditions": { "temperature": "295 K", "elongation rate": "1.7 μm s−1" } }
# JSON for NO-PFZ1 specimen: { "alloy_designation/alloy_formula": "NIMONIC PE16, NO-PFZ1", "state": "Monomodal, PFZ-free", "yield strength": "628 MPa", "grain size": "6.1 μm", "γ' volume fraction": "0.061", "γ' average radius": "25 nm" } JSON for PFZ1 specimen: { "alloy_designation/alloy_formula": "NIMONIC PE16, PFZ1", "state": "Monomodal, PFZs at grain boundaries", "yield strength": "495 MPa", "grain size": "265 μm", "γ' volume fraction": "0.061", "γ' average radius": "25 nm", "PFZ width": "650 nm" } JSON for NO-PFZ2 specimen: { "alloy_designation/alloy_formula": "NIMONIC PE16, NO-PFZ2", "state": "Bimodal, PFZ-free", "yield strength": "750 MPa", "large γ' volume fraction": "0.073", "large γ' average radius": "26.5 nm", "small γ' volume fraction": "0.039", "small γ' average radius": "4.1 nm" } JSON for PFZ2 specimen: { "alloy_designation/alloy_formula": "NIMONIC PE16, PFZ2", "state": "Bimodal, PFZs at grain boundaries", "yield strength": "659 MPa", "large γ' volume fraction": "0.073", "large γ' average radius": "26.5 nm", "small γ' volume fraction": "0.039", "small γ' average radius": "4.1 nm" }
# Processed and saved 10.1016-j.actamat.2005.02.010.json to Data/PaperJson/JSON-All-Results
# JSON for Samples As-solution extrusion: { "Tension": { "YS (MPa)": "243 ± 3", "PS (MPa)": "350 ± 4", "UP (%)": "6.6 ± 0.5" }, "Compression": { "YS (MPa)": "143 ± 2", "PS (MPa)": "433 ± 3", "UP (%)": "18.6 ± 0.3" } } JSON for Samples Direct aging: { "Tension": { "YS (MPa)": "276 ± 5", "PS (MPa)": "391 ± 6", "UP (%)": "4.1 ± 0.6" }, "Compression": { "YS (MPa)": "230 ± 1", "PS (MPa)": "514 ± 3", "UP (%)": "11.0 ± 0.2" } } JSON for Samples Unidirectional torsion and then aging: { "Tension": { "YS (MPa)": "272 ± 4", "PS (MPa)": "361 ± 5", "UP (%)": "2.6 ± 0.8" }, "Compression": { "YS (MPa)": "252 ± 1", "PS (MPa)": "506 ± 4", "UP (%)": "12.8 ± 0.3" } } JSON for Samples Reciprocating torsion and then aging: { "Tension": { "YS (MPa)": "308 ± 6", "PS (MPa)": "457 ± 3", "UP (%)": "3.5 ± 0.6" }, "Compression": { "YS (MPa)": "256 ± 2", "PS (MPa)": "550 ± 3", "UP (%)": "11.3 ± 0.3" } }
# Processed and saved 10.1007-s11665-019-04152-6.json to Data/PaperJson/JSON-All-Results
# { "DOI": "10.1016/j.jallcom.2018.02.271", "Journal": "Journal of Alloys and Compounds", "Keywords": [ "TiN nanoparticles", "Al-Zn-Mg-Cu alloy", "Solution-aging treatment", "Microstructures", "Mechanical properties", "Electrical conductivities" ], "Sections": [], "Title": "Precipitation behaviors and properties of solution-aging Al-Zn-Mg-Cu alloy refined with TiN nanoparticles", "abstract": "The precipitation hardening characteristics, aging precipitation behaviors, mechanical properties and electrical conductivity of the Al-Zn-Mg-Cu alloy refined with TiN nanoparticles (well supported by Ti microparticles) are investigated, in detail. The results show that, compared with the alloy with only Ti or without any refiner, the TiN nanoparticle addition improves the solution of the alloying elements, retains the fine grains of the Al-Zn-Mg-Cu alloy during the solid solution process and enhances the Vickers hardness of the solution treated alloy. More importantly, during the aging process, the TiN nanoparticle addition promotes the diffusely uniform precipitation of the G.P. zones, eta' phase and eta phase, and accelerates the evolution to the G.P. zones from the supersaturated solid solution in the matrix, but inhibits the precipitations of eta' phase and eta phase. The yield stress (569.8 MPa), ultimate tensile stress (595.5 MPa) and elongation (18.1%) of the alloy refined with TiN are higher than those with only Ti or without any refiner. In addition, the electrical conductivities of the aged alloy with TiN are lower than those of the alloy with only Ti or without any refiner. (c) 2018 Elsevier B.V. All rights reserved." }
# { "Alloy_Designation/Alloy_Formula": "Al-7.0Zn-2.5Mg-2.5Cu", "Melting": "730°C", "Casting": "N/A", "Homo": "470°C, 24h", "Extrusion": { "Extrusion Temperature": "400°C", "Ram Speed": "10 mm/s", "Extrusion Ratio": "6.9", "Bar Diameter": "N/A", "Extrusion Speed": "N/A", "Starting Diameter": "N/A", "Final Diameter": "N/A" }, "Solution-treated": "473°C, 2h", "Quenching": "Water Quenching at 60°C", "Aging": "120°C, 0-120h" }
# JSON for Al-Zn-Mg-Cu alloy with No refiner: { "Precipitates": { "G.P.": { "Peak temperature/T p , °C": "83.4", "Activation energy/E a , kJ/mol": "154.1" }, "η′": { "Peak temperature/T p , °C": "191.4", "Activation energy/E a , kJ/mol": "106.8" }, "η": { "Peak temperature/T p , °C": "235.6", "Activation energy/E a , kJ/mol": "94.9" } } } JSON for Al-Zn-Mg-Cu alloy with Ti refiner: { "Precipitates": { "G.P.": { "Peak temperature/T p , °C": "86.1", "Activation energy/E a , kJ/mol": "152.2" }, "η′": { "Peak temperature/T p , °C": "187.4", "Activation energy/E a , kJ/mol": "108.1" }, "η": { "Peak temperature/T p , °C": "233.1", "Activation energy/E a , kJ/mol": "95.6" } } } JSON for Al-Zn-Mg-Cu alloy with TiN/Ti refiner: { "Precipitates": { "G.P.": { "Peak temperature/T p , °C": "93.5", "Activation energy/E a , kJ/mol": "147.5" }, "η′": { "Peak temperature/T p , °C": "185.2", "Activation energy/E a , kJ/mol": "108.7" }, "η": { "Peak temperature/T p , °C": "232.9", "Activation energy/E a , kJ/mol": "95.7" } } }
# { "Alloy_Designation/Alloy_Formula": "Al-Zn-Mg-Cu, TiN nanoparticle refined", "State": "Aged", "Grain_Size": { "Without_Refiner": "378 μm", "With_Ti": "212 μm", "With_TiN": "136 μm" }, "Vickers_Hardness": { "Without_Refiner": "193 HV", "With_Ti": "197 HV", "With_TiN": "202.4 HV" }, "Peak_Aged_Hardness": { "Without_Refiner": "197.2 HV", "With_Ti": "201.5 HV", "With_TiN": "208.3 HV" }, "Yield_Strength": "569.8 MPa", "Ultimate_Tensile_Strength": "595.5 MPa", "Elongation": "18.1%", "Precipitate_Free_Zone_Width": { "Without_Refiner": "70 nm", "With_Ti": "50 nm", "With_TiN": "30 nm" }, "Electrical_Conductivity": { "With_TiN": "Lower than without refiner or with only Ti" }, "Precipitates": { "G.P._Zones": "Diffusely uniform precipitation", "Eta'": "Inhibited precipitation", "Eta": "Inhibited precipitation" }, "Fracture_Behavior": "Transgranular ductile manner with fine dimples" }
# Processed and saved 10.1016-j.jallcom.2018.02.271.json to Data/PaperJson/JSON-All-Results
# Structured information for each alloy sample: JSON for Sample Ru22Cu7: { "Ru/Cu (SRu3p3/2× 2.48)/SCu2p3/2": { "[Surface = bulk]": "3.14", "As-leached": "2.63", "Annealed (T/°C)": "2.03 (200)" }, "EXAFS fitting data at the Cu K-edge": { "As-leached": { "Cu–O": { "N1": "3.2", "R1": "1.92", "σ21": "0.0064" }, "Cu–Cu": { "N2": "2.5", "R2": "2.55", "σ22": "0.0200" }, "Cu–Ru": { "N3": "3.9", "R3": "2.65", "σ23": "0.013" }, "Relative ratio": { "Cu–O": "58", "Cu–Cu": "12", "Cu–Ru": "30" } }, "Annealed 200 °C": { "Cu–O": { "N1": "2.9", "R1": "1.89", "σ21": "0.0083" }, "Cu–Cu": { "N2": "7.4", "R2": "2.55", "σ22": "0.0200" }, "Cu–Ru": { "N3": "4.2", "R3": "2.65", "σ23": "0.011" }, "Relative ratio": { "Cu–O": "23", "Cu–Cu": "34", "Cu–Ru": "43" } }, "Annealed 250 °C": { "Cu–O": { "N1": "2.8", "R1": "1.89", "σ21": "0.0073" }, "Cu–Cu": { "N2": "8.2", "R2": "2.55", "σ22": "0.0200" }, "Cu–Ru": { "N3": "4.2", "R3": "2.65", "σ23": "0.008" }, "Relative ratio": { "Cu–O": "25", "Cu–Cu": "29", "Cu–Ru": "45" } }, "Annealed 300 °C": { "Cu–O": { "N1": "1.6", "R1": "1.87", "σ21": "0.0023" }, "Cu–Cu": { "N2": "7.7", "R2": "2.55", "σ22": "0.0200" }, "Cu–Ru": { "N3": "4.2", "R3": "2.65", "σ23": "0.010" }, "Relative ratio": { "Cu–O": "20", "Cu–Cu": "35", "Cu–Ru": "44" } }, "Annealed 350 °C": { "Cu–O": { "N1": "1.4", "R1": "1.80", "σ21": "0.0037" }, "Cu–Cu": { "N2": "9.3", "R2": "2.55", "σ22": "0.0200" }, "Cu–Ru": { "N3": "3.1", "R3": "2.65", "σ23": "N/A" }, "Relative ratio": { "Cu–O": "N/A", "Cu–Cu": "N/A", "Cu–Ru": "N/A" } } }, "CO oxidation activity": { "40 °C": "2", "55 °C": "8", "75 °C": "40 (4)", "100 °C": "85 (6)", "120 °C": "100 (9)", "Tloa /°C": "64" } } JSON for Sample Ru17Cu12.5: { "Ru/Cu (SRu3p3/2× 2.48)/SCu2p3/2": { "[Surface = bulk]": "1.36", "As-leached": "1.67", "Annealed (T/°C)": "0.85 (300)" }, "EXAFS fitting data at the Cu K-edge": { "As-leached": { "Cu–O": { "N1": "3.0", "R1": "1.89", "σ21": "0.0079" }, "Cu–Cu": { "N2": "4.7", "R2": "2.51", "σ22": "0.0083" }, "Cu–Ru": { "N3": "N/A", "R3": "N/A", "σ23": "N/A" }, "Relative ratio": { "Cu–O": "35", "Cu–Cu": "65", "Cu–Ru": "N/A" } }, "Annealed 250 °C": { "Cu–O": { "N1": "2.2", "R1": "2.02", "σ21": "0.0158" }, "Cu–Cu": { "N2": "8.5", "R2": "2.51", "σ22": "0.0075" }, "Cu–Ru": { "N3": "N/A", "R3": "N/A", "σ23": "N/A" }, "Relative ratio": { "Cu–O": "16", "Cu–Cu": "84", "Cu–Ru": "N/A" } }, "Annealed 300 °C": { "Cu–O": { "N1": "1.9", "R1": "2.04", "σ21": "0.0010" }, "Cu–Cu": { "N2": "8.1", "R2": "2.51", "σ22": "0.0076" }, "Cu–Ru": { "N3": "N/A", "R3": "N/A", "σ23": "N/A" }, "Relative ratio": { "Cu–O": "14", "Cu–Cu": "86", "Cu–Ru": "N/A" } } }, "CO oxidation activity": { "40 °C": "2.5", "55 °C": "10", "75 °C": "35 (10)", "100 °C": "85 (16)", "120 °C": "100 (30)", "Tloa /°C": "70" } } JSON for Sample Ru10Cu20: { "Ru/Cu (SRu3p3/2× 2.48)/SCu2p3/2": { "[Surface = bulk]": "0.50", "As-leached": "0.13", "Annealed (T/°C)": "0.02 (300)" }, "EXAFS fitting data at the Cu K-edge": { "As-leached": { "Cu–O": { "N1": "4.1", "R1": "1.92", "σ21": "0.0066" }, "Cu–Cu": { "N2": "5.5", "R2": "2.54", "σ22": "0.0098" }, "Cu–Ru": { "N3": "N/A", "R3": "N/A", "σ23": "N/A" }, "Relative ratio": { "Cu–O": "41", "Cu–Cu": "59", "Cu–Ru": "N/A" } }, "Annealed 250 °C": { "Cu–O": { "N1": "2.2", "R1": "1.93", "σ21": "0.0077" }, "Cu–Cu": { "N2": "7.1", "R2": "2.53", "σ22": "0.0089" }, "Cu–Ru": { "N3": "N/A", "R3": "N/A", "σ23": "N/A" }, "Relative ratio": { "Cu–O": "15", "Cu–Cu": "85", "Cu–Ru": "N/A" } }, "Annealed 300 °C": { "Cu–O": { "N1": "2.0", "R1": "1.94", "σ21": "0.0081" }, "Cu–Cu": { "N2": "6.9", "R2": "2.53", "σ22": "0.0089" }, "Cu–Ru": { "N3": "N/A", "R3": "N/A", "σ23": "N/A" }, "Relative ratio": { "Cu–O": "12", "Cu–Cu": "88", "Cu–Ru": "N/A" } } }, "CO oxidation activity": { "40 °C": "1.5", "55 °C": "8", "75 °C": "38 (12)", "100 °C": "80 (20)", "120 °C": "90 (35)", "Tloa /°C": "72" } } Please note that some information was not provided in the original data and is marked as "N/A".
# Processed and saved 10.1039-b811775f.json to Data/PaperJson/JSON-All-Results
# { "Sections": [], "abstract": "Both the formability and hardness of the age-hardenable AA6061 aluminum alloy sheet are highly dependent on the type of the heat treatment. In this research, to simultaneously improve the formability and the final hardness of a truncated pyramid from the AA6061 aluminum alloy formed by single point incremental forming (SPIF), three different heat treatment cycles have been investigated. The considered cycles include solid solution/SPIF/aging (the cycle I), solid solution/aging/SPIF (the cycle II), and annealing/SPIF/solid solution/aging (the cycle III). The maximum forming depth achievable at certain wall angles before fracture was considered as a formability indicator. Microstructural studies were carried out using optical and scanning electron microscopy and differential scanning calorimetry. The obtained results show that the best condition among the investigated heat treatment cycles for SPIF of the 70 degrees wall angle is cold working of the annealed sheet in the cycle III which results in an improvement of 100% in the forming depth and an increase of 2% in the hardness by the subsequent artificial aging treatment, as compared to the as-received condition. Also, microstructural studies revealed that the solution temperature and time considerably affect the formability and hardness of the final formed part during the cycle I." }
# { "Alloy_Designation/Alloy_Formula": "AA6061 aluminum alloy", "SPIF": { "Initial Blank Dimensions": "100 mm x 100 mm", "Formed Shape": "truncated pyramid", "Major Base Dimensions": "58 mm x 58 mm", "Forming Tool Material": "cold working tool steel", "Forming Tool Diameter": "10 mm", "Tool Path": "spiral", "Vertical Pitch": "1 mm", "Feed Rate": "1260 mm/min", "Spindle Rotation": "No", "Lubricant": "hydraulic oil", "Backing Plate Hole Dimensions": "60 mm x 60 mm" }, "Heat_Treatment_Cycle_I": { "Solution Treatment": { "Temperature Range": "530°C to 560°C", "Time Range": "30 min to 120 min", "Solidus Point": "580°C" }, "Artificial Aging": "180°C for 6 h", "Natural Aging": "Room temperature for 14 days" }, "Heat_Treatment_Cycle_II": { "Solution Treatment": "545°C for 75 min", "Artificial Aging": "Specified temperature and time from Section 2.3", "Natural Aging": "Specified temperature and time from Section 2.3", "SPIF": "truncated pyramid with 50° and 70° wall angles" }, "Heat_Treatment_Cycle_III": { "Annealing": "Significant hardness reduction", "SPIF": "70° wall angle pyramid", "Solid Solution Treatment": "Specified temperature and time from Section 2.3", "Aging": "Specified temperature and time from Section 2.3" }, "Formability_Indicator": "Maximum forming depth before fracture", "Microstructural_Studies": "Optical and scanning electron microscopy, differential scanning calorimetry" }
# JSON for AA6061 Aluminum Alloy: { "Material": "AA6061", "Composition (weight %)": { "Al": "Base", "Si": "0.73", "Fe": "0.33", "Cu": "0.26", "Mn": "0.04", "Mg": "0.88", "Cr": "0.17", "Zn": "0.05", "Ti": "0.02", "Others": "0.02" }, "Mechanical Properties": { "Young’s modulus (GPa)": "74.2", "Yield strength (MPa)": "349.2", "Tensile strength (MPa)": "381.1", "Fracture elongation (%)": "6.95" }, "Grain Sizes": { "As received": { "Average grain size (µm)": "20.88", "+ 50° SPIF": "17.75", "+ 70° SPIF": "16.20" }, "Annealed": { "Average grain size (µm)": "20.40", "+ 70° SPIF": "19.13", "+ 70° SPIF + T6*": "23.14" }, "Solution treated": { "Cycle II +T6": "20.48", "Cycle I +T4*": "21.69", "75 min–530 °C": "19.85", "75 min–545 °C": "18.19", "75 min–560 °C": "15.75", "75 min–545 °C+70° SPIF + T6": "19.48" } } }
# { "Alloy_Designation/Alloy_Formula": "AA6061", "State": "Cycle I", "Solution_Treatment": { "Temperature": ["530°C", "545°C", "560°C"], "Time": ["30 min", "75 min", "120 min"] }, "Aging_Treatment": { "Artificial": "180°C for 6 hours", "Natural": "Room temperature for 14 days" }, "Formability": { "Improvement": "Up to 81% for 530°C at 30 min solution treatment compared to as-received" }, "Hardness": { "Initial": "108.9 HV0.1", "Post_Solution_Treatment": "Varies with temperature and time", "Final_After_Aging": "Varies with temperature and time, up to 10.5% higher than as-received" } } { "Alloy_Designation/Alloy_Formula": "AA6061", "State": "Cycle II", "Pre_SPIF_Aging": { "Artificial": "Specific time and temperature not provided", "Natural": "14 days" }, "Hardness": { "Pre_SPIF": "81.8 HV0.1 (Natural), 112 HV0.1 (Artificial)", "Post_SPIF": "Varies, highest for artificially aged sheet" }, "Formability": { "Reduction": "75% for 50° wall angle artificially aged sheet compared to as-received" } } { "Alloy_Designation/Alloy_Formula": "AA6061", "State": "Cycle III", "Annealing_Treatment": "Significant hardness reduction to 38 HV0.1", "Formability": { "Improvement": "100% for 70° pyramid compared to as-received" }, "Hardness": { "Post_Annealing": "38 HV0.1", "Post_Cold_Working": "Varies with wall angle", "Final_After_Aging": "Comparable to as-received after artificial aging" } }
# Processed and saved 10.1007-s00170-019-04167-2.json to Data/PaperJson/JSON-All-Results
# { "DOI": "10.1016/j.actamat.2007.08.033", "Journal": "Acta Materialia", "Keywords": [ "Magnesium", "Mg–Zn–Gd", "Precipitation", "β′-phase", "Long period stacking ordered structure" ], "Sections": [], "Title": "Formation of 14H long period stacking ordered structure and profuse stacking faults in Mg–Zn–Gd alloys during isothermal aging at high temperature", "abstract": "This paper proposes a time-temperature-transformation diagram of an Mg-Zn-Gd alloy. An Mg97Zn1Gd2 (at.%) alloy shows different precipitation sequences at low, medium and high temperatures. Low-temperature aging at < 523 K brings about coherent beta'-phase precipitation to a alpha-Mg solid solution, resulting in increase in strength of the alloys. However, aging at medium and high temperatures > 623 K led to strengthening of the Mg-Zn-Gd alloy, owing to the formation of profuse stacking faults and 14H long period stacking ordered structure from the supersaturated a-Mg matrix, respectively. (c) 2007 Acta Materialia Inc. Published by Elsevier Ltd. All rights reserved." }
# { "Alloy_Designation/Alloy_Formula": "Mg97Zn1Gd2", "Casting": "N/A", "Melting": "N/A", "Solution-treated": "793 K, 2 h", "Water Quenching": "Yes", "Annealing": "473 K, 150 h for peak-aged specimen; 573 K, 10 h; 673 K, 10 h and 30 h; 773 K, N/A", "Aging": "473 K, 60 h for β′-phase precipitation; 673 K, N/A for LPSO structure formation", "Natural Aging": "N/A", "Cold-Rolling": "N/A", "Hot-Rolling": "N/A", "Extrusion": "N/A", "Forge": "N/A" }
# { "alloy_designation/alloy_formula": "Mg97Zn1Gd2", "state": "as-cast", "microstructure": { "secondary phase": "Mg3Gd-type compound", "grain boundary characteristics": "observed in the α-Mg matrix and in grain boundaries" }, "mechanical_properties": { "Vickers micro-hardness": "<100Hv0.1" } } { "alloy_designation/alloy_formula": "Mg97Zn1Gd2", "state": "solution-treated", "microstructure": { "secondary phase": "Mg3Gd-type compound", "volume fraction": "decreased" }, "mechanical_properties": { "Vickers micro-hardness": "128Hv0.1 after aging at 473 K" } } { "alloy_designation/alloy_formula": "Mg97Zn1Gd2", "state": "aged", "microstructure": { "β′-phase": "precipitation after 60 h at 473 K", "β1-phase": "precipitation after 150 h at 473 K", "β-phase": "plate-like precipitates after 250 h at 473 K", "stacking faults": "observed at 573 K for 10 h", "LPSO structure": "observed at 673 K" }, "mechanical_properties": { "tensile_strength": "230 MPa at 573 K", "yield_strength": "decreased above 623 K" } } { "alloy_designation/alloy_formula": "Mg98Gd2", "state": "aged at 573 K for 10 h", "microstructure": { "β-phase": "precipitation observed" }, "mechanical_properties": { "tensile_strength": "N/A", "yield_strength": "N/A" } } { "alloy_designation/alloy_formula": "Mg96.5Zn1Gd2.5", "state": "N/A", "microstructure": { "2H and 14H structures": { "chemical compositions": { "2H": "Mg–0.2 ± 0.1 at.% Zn–1.4 ± 0.1 at.% Gd", "14H": "Mg–11 ± 1.0 at.% Zn–8 ± 1.0 at.% Gd" } } }, "mechanical_properties": { "tensile_yield_strength": "228 MPa", "elongation": "0.4%" } }
# Processed and saved 10.1016-j.actamat.2007.08.033.json to Data/PaperJson/JSON-All-Results
# Structured format for Spec. 2: - Pre-com. (%): 0 (Compressibility), 0 (Recovery) - Temp. (K): 523 (Compressibility), 523 (Recovery) - Time (min): 60 (Compressibility), 60 (Recovery) - Com. (%): 2.7 (Compressibility) - Rec. (%): 95.4 (Recovery) Structured format for Spec. 3: - Pre-com. (%): 0 (Compressibility), 0 (Recovery) - Temp. (K): 673 (Compressibility), 673 (Recovery) - Time (min): 120 (Compressibility), 120 (Recovery) - Com. (%): 3 (Compressibility) - Rec. (%): 73.9 (Recovery) Structured format for Spec. 4: - Pre-com. (%): 0 (Compressibility), 0 (Recovery) - Temp. (K): 823 (Compressibility), 823 (Recovery) - Time (min): 180 (Compressibility), 180 (Recovery) - Com. (%): 2.8 (Compressibility) - Rec. (%): 85.7 (Recovery) Structured format for Spec. 5: - Pre-com. (%): 0.20 (Compressibility), 0.20 (Recovery) - Temp. (K): 523 (Compressibility), 523 (Recovery) - Time (min): 180 (Compressibility), 180 (Recovery) - Com. (%): 3.4 (Compressibility) - Rec. (%): 91.9 (Recovery) Structured format for Spec. 6: - Pre-com. (%): 0.20 (Compressibility), 0.20 (Recovery) - Temp. (K): 673 (Compressibility), 673 (Recovery) - Time (min): 60 (Compressibility), 60 (Recovery) - Com. (%): 4 (Compressibility) - Rec. (%): 86.5 (Recovery) Structured format for Spec. 7: - Pre-com. (%): 0.20 (Compressibility), 0.20 (Recovery) - Temp. (K): 823 (Compressibility), 823 (Recovery) - Time (min): 120 (Compressibility), 120 (Recovery) - Com. (%): 4.9 (Compressibility) - Rec. (%): 85.7 (Recovery) Structured format for Spec. 8: - Pre-com. (%): 0.70 (Compressibility), 0.70 (Recovery) - Temp. (K): 523 (Compressibility), 523 (Recovery) - Time (min): 120 (Compressibility), 120 (Recovery) - Com. (%): 2.7 (Compressibility) - Rec. (%): 91 (Recovery) Structured format for Spec. 9: - Pre-com. (%): 0.70 (Compressibility), 0.70 (Recovery) - Temp. (K): 673 (Compressibility), 673 (Recovery) - Time (min): 180 (Compressibility), 180 (Recovery) - Com. (%): 3.9 (Compressibility) - Rec. (%): 72.1 (Recovery) Structured format for Spec. 10: - Pre-com. (%): 0.70 (Compressibility), 0.70 (Recovery) - Temp. (K): 823 (Compressibility), 823 (Recovery) - Time (min): 60 (Compressibility), 60 (Recovery) - Com. (%): 3.4 (Compressibility) - Rec. (%): 89.4 (Recovery) Structured format for Spec. k1: - Pre-com. (%): 2.83 (Compressibility), 85.00 (Recovery) - Temp. (K): 2.93 (Compressibility), 92.77 (Recovery) - Time (min): 3.37 (Compressibility), 90.43 (Recovery) Structured format for Spec. k2: - Pre-com. (%): 4.10 (Compressibility), 88.03 (Recovery) - Temp. (K): 3.63 (Compressibility), 77.50 (Recovery) - Time (min): 3.53 (Compressibility), 83.53 (Recovery) Structured format for Spec. k3: - Pre-com. (%): 3.33 (Compressibility), 84.17 (Recovery) - Temp. (K): 3.70 (Compressibility), 86.93 (Recovery) - Time (min): 3.37 (Compressibility), 83.23 (Recovery) Structured format for Spec. Range: - Pre-com. (%): 1.27 (Compressibility), 3.87 (Recovery) - Temp. (K): 0.77 (Compressibility), 15.27 (Recovery) - Time (min): 0.17 (Compressibility), N/A (Recovery)
# Processed and saved 10.1016-j.jallcom.2012.07.110.json to Data/PaperJson/JSON-All-Results
# { "Sections": [], "abstract": "Titanium (Ti) alloys can be applied for biomaterials of artificial bone and bone repair. However, Ti alloys are bioinert materials, i.e., they have low bone formation ability. The heat treatments of Ti alloys promote bone formation ability, but the mechanism for the promotion has not been well understood. The effects of heat treatment of titanium, zirconium, niobium, and tantalum metals on the behavior of MC3T3-E1 osteoblast-like cells during culturing in vitro were examined. The specimens were heated at temperatures from 400 to 800 degrees C in the air for oxidation. The oxidation of the metal surface by the heat treatment changed its surface to hydrophilic and increased the surface roughness. Cell extension and proliferation were influenced not by metal species and their oxides but by surface roughness and wettability. The hydrophilicity and smooth surface improved cell extension and cell proliferation." }
# { "Alloy_Designation/Alloy_Formula": "Titanium (Ti)", "Purity": "99.5%", "Sample_Preparation": { "Cutting": "circular plates, diameter: 3 mm, thickness: 0.2 mm", "Polishing": "mechanically mirror-polished with alumina powder, particle size: 0.3 µm", "Cleaning": "ultrasonically rinsed in acetone and ethanol" }, "Heat-treated": "400–800°C, 3.6 ks", "Sterilization": "121°C, 1.2 ks" }, { "Alloy_Designation/Alloy_Formula": "Zirconium (Zr)", "Purity": "99.2%", "Sample_Preparation": { "Cutting": "circular plates, diameter: 3 mm, thickness: 0.2 mm", "Polishing": "mechanically mirror-polished with alumina powder, particle size: 0.3 µm", "Cleaning": "ultrasonically rinsed in acetone and ethanol" }, "Heat-treated": "400–800°C, 3.6 ks", "Sterilization": "121°C, 1.2 ks" }, { "Alloy_Designation/Alloy_Formula": "Niobium (Nb)", "Purity": "99.9%", "Sample_Preparation": { "Cutting": "circular plates, diameter: 3 mm, thickness: 0.2 mm", "Polishing": "mechanically mirror-polished with alumina powder, particle size: 0.3 µm", "Cleaning": "ultrasonically rinsed in acetone and ethanol" }, "Heat-treated": "400–800°C, 3.6 ks", "Sterilization": "121°C, 1.2 ks" }, { "Alloy_Designation/Alloy_Formula": "Tantalum (Ta)", "Purity": "99.95%", "Sample_Preparation": { "Cutting": "circular plates, diameter: 3 mm, thickness: 0.2 mm", "Polishing": "mechanically mirror-polished with alumina powder, particle size: 0.3 µm", "Cleaning": "ultrasonically rinsed in acetone and ethanol" }, "Heat-treated": "400–800°C, 3.6 ks", "Sterilization": "121°C, 1.2 ks" }
# { "alloy_designation/alloy_formula": "Ti", "state": "as-prepared", "microstructure": "hcp", "XRD_phase": "α-phase", "surface roughness (Ra, μm)": "<0.2", "surface area ratio (r)": "N/A", "water contact angle (WCA, °)": "60", "cell proliferation": "improved at 400°C", "SEM_surface_morphology": "unchanged by heat treatment" } { "alloy_designation/alloy_formula": "Ti", "state": "heat-treated at 700°C", "XRD_phase": "α-phase, rutile phase", "surface roughness (Ra, μm)": "unchanged", "surface area ratio (r)": "increased", "water contact angle (WCA, °)": "<10", "cell proliferation": "decreased with increasing temperature" } { "alloy_designation/alloy_formula": "Ti", "state": "heat-treated at 800°C", "XRD_phase": "rutile phase", "surface roughness (Ra, μm)": "unchanged", "surface area ratio (r)": "increased", "water contact angle (WCA, °)": "<10", "cell proliferation": "decreased with increasing temperature" } { "alloy_designation/alloy_formula": "Zr", "state": "as-prepared and heat-treated under 600°C", "microstructure": "hcp", "XRD_phase": "α-phase", "surface roughness (Ra, μm)": "<0.2", "surface area ratio (r)": "unchanged", "water contact angle (WCA, °)": "60", "cell proliferation": "smaller at 400°C compared to other metals", "SEM_surface_morphology": "unchanged by heat treatment" } { "alloy_designation/alloy_formula": "Zr", "state": "heat-treated at 700°C", "XRD_phase": "α-phase, zirconium oxide phase", "surface roughness (Ra, μm)": "unchanged", "surface area ratio (r)": "unchanged", "water contact angle (WCA, °)": "<10", "cell proliferation": "decreased with increasing temperature" } { "alloy_designation/alloy_formula": "Zr", "state": "heat-treated at 800°C", "XRD_phase": "α-phase", "surface roughness (Ra, μm)": "unchanged", "surface area ratio (r)": "unchanged", "water contact angle (WCA, °)": "<10", "cell proliferation": "decreased with increasing temperature" } { "alloy_designation/alloy_formula": "Nb", "state": "as-prepared", "microstructure": "bcc", "XRD_phase": "β-phase", "surface roughness (Ra, μm)": "<0.2", "surface area ratio (r)": "N/A", "water contact angle (WCA, °)": "60", "cell proliferation": "improved at 400°C", "SEM_surface_morphology": "smooth" } { "alloy_designation/alloy_formula": "Nb", "state": "heat-treated at 400°C", "XRD_phase": "β-phase", "surface roughness (Ra, μm)": "increased", "surface area ratio (r)": "unchanged", "water contact angle (WCA, °)": "<10", "cell proliferation": "decreased with increasing temperature", "SEM_surface_morphology": "rough with spherical oxide particles" } { "alloy_designation/alloy_formula": "Nb", "state": "heat-treated over 600°C", "XRD_phase": "niobium oxide", "surface roughness (Ra, μm)": "could not be measured due to large cracks", "surface area ratio (r)": "unchanged", "water contact angle (WCA, °)": "<10", "cell proliferation": "decreased with increasing temperature", "SEM_surface_morphology": "large cracks on surface" } { "alloy_designation/alloy_formula": "Ta", "state": "as-prepared and heat-treated under 500°C", "microstructure": "bcc", "XRD_phase": "β-phase", "surface roughness (Ra, μm)": "<0.2", "surface area ratio (r)": "N/A", "water contact angle (WCA, °)": "60", "cell proliferation": "improved at 400°C", "SEM_surface_morphology": "smooth" } { "alloy_designation/alloy_formula": "Ta", "state": "heat-treated over 600°C", "XRD_phase": "tantalum oxide", "surface roughness (Ra, μm)": "increased", "surface area ratio (r)": "slightly increased", "water contact angle (WCA, °)": "<10", "cell proliferation": "hardly proliferated", "SEM_surface_morphology": "surface cracks" }
# Processed and saved 10.1557-s43578-022-00691-2.json to Data/PaperJson/JSON-All-Results
# JSON for Initial material: { "Scan step size, μm": "0.25", "Map area, μm^2": "400 × 400", "Number of pixels": "2,957,724", "Number of grains": "614", "Yield strength, MPa": "136 ± 1.0", "Ultimate tensile strength, MPa": "349 ± 2.0", "Ductility, %": "28 ± 1.0" } JSON for 30 pct. rolling: { "Scan step size, μm": "0.7", "Map area, μm^2": "400 × 400", "Number of pixels": "589,463", "Number of grains": "2514" } JSON for 40 pct. rolling: { "Scan step size, μm": "0.25", "Map area, μm^2": "300 × 300", "Number of pixels": "1,661,683", "Number of grains": "6532", "Yield strength, MPa": "431 ± 0.6", "Ultimate tensile strength, MPa": "478 ± 0.6", "Ductility, %": "7.5 ± 0.2", "Measured yield strength, MPa": "431", "Threshold stress, MPa": "110", "Calculated dislocation strengthening, MPa": "214", "Predicted LAB strengthening, MPa": "107" } JSON for 60 pct. rolling: { "Scan step size, μm": ["0.7", "0.25"], "Map area, μm^2": ["400 × 400", "200 × 250"], "Number of pixels": ["589,463", "924,578"], "Number of grains": ["3089", "2379"], "Yield strength, MPa": "462 ± 5.1", "Ultimate tensile strength, MPa": "502 ± 3.8", "Ductility, %": "6.5 ± 0.3", "Measured yield strength, MPa": "462", "Threshold stress, MPa": "110", "Calculated dislocation strengthening, MPa": "226", "Predicted LAB strengthening, MPa": "126" } JSON for 80 pct. rolling: { "Scan step size, μm": "0.25", "Map area, μm^2": "200 × 250", "Number of pixels": "924,578", "Number of grains": "4679", "Yield strength, MPa": "521 ± 1.3", "Ultimate tensile strength, MPa": "553 ± 0.4", "Ductility, %": "4.5 ± 0.2", "Measured yield strength, MPa": "521", "Threshold stress, MPa": "110", "Calculated dislocation strengthening, MPa": "271", "Predicted LAB strengthening, MPa": "140" }
# Processed and saved 10.1016-j.msea.2018.12.103.json to Data/PaperJson/JSON-All-Results
# Structured format for Analysis of Fe-Mn rosette particles 1: - Al (wt%): 59.1 - Si (wt%): 9.2 - Cr (wt%): 4.3 - Mn (wt%): 6.9 - Fe (wt%): 19.7 - Cu (wt%): 0.8 Structured format for Analysis of Fe-Mn rosette particles 2: - Al (wt%): 58.3 - Si (wt%): 9.2 - Cr (wt%): 4.5 - Mn (wt%): 6.9 - Fe (wt%): 20.2 - Cu (wt%): 0.9 Structured format for Analysis of Fe-Mn rosette particles 3: - Al (wt%): 59.5 - Si (wt%): 10.6 - Cr (wt%): 3.7 - Mn (wt%): 6.4 - Fe (wt%): 18.9 - Cu (wt%): 1.1 Structured format for Analysis of Fe-Mn rosette particles 4: - Al (wt%): 67.5 - Si (wt%): 10.2 - Cr (wt%): 2.3 - Mn (wt%): 4.7 - Fe (wt%): 13.4 - Cu (wt%): 1.9 Structured format for Analysis of Fe-Mn rosette particles 5: - Al (wt%): 58.7 - Si (wt%): 9.6 - Cr (wt%): 4.1 - Mn (wt%): 6.8 - Fe (wt%): 19.8 - Cu (wt%): 1.0 Structured format for Analysis of Fe-Mn rosette particles 6: - Al (wt%): 59.0 - Si (wt%): 10.3 - Cr (wt%): 3.3 - Mn (wt%): 6.6 - Fe (wt%): 19.5 - Cu (wt%): 1.4 Structured format for Analysis of Fe-Mn rosette particles 7: - Al (wt%): 64.3 - Si (wt%): 12.0 - Cr (wt%): 2.9 - Mn (wt%): 4.8 - Fe (wt%): 14.8 - Cu (wt%): 1.3 Structured format for Analysis of Fe-Mn rosette particles 8: - Al (wt%): 58.2 - Si (wt%): 9.8 - Cr (wt%): 3.0 - Mn (wt%): 6.4 - Fe (wt%): 20.1 - Cu (wt%): 2.5 Structured format for Analysis of Fe-Mn rosette particles 9: - Al (wt%): 59.0 - Si (wt%): 8.9 - Cr (wt%): 3.8 - Mn (wt%): 6.7 - Fe (wt%): 19.9 - Cu (wt%): 1.7 Structured format for Analysis of Fe-Mn rosette particles 10: - Al (wt%): 61.1 - Si (wt%): 11.1 - Cr (wt%): 3.6 - Mn (wt%): 5.9 - Fe (wt%): 17.5 - Cu (wt%): 0.9 Structured format for Analysis of Fe-Mn rosette particles 11: - Al (wt%): 59.0 - Si (wt%): 9.4 - Cr (wt%): 4.0 - Mn (wt%): 6.8 - Fe (wt%): 19.9 - Cu (wt%): 0.9
# Processed and saved 10.1007-s11665-018-3478-4.json to Data/PaperJson/JSON-All-Results
# JSON for Catalyst Pt/C: { "j at 0.6V (mA/cm2)": "336.8", "-b (mV/Dec)": "47.0", "j 0 (mA/cm2)": "1.59×10−6", "R (Ω-cm2)": "0.6270", "m (mV)": "1.4", "n (cm2/mA)": "0.0065", "R 2": "0.9990", "E corr (mV)": "−224", "b a (mV/dec)": "286", "b c (mV/dec)": "262", "j corr (mA/cm2)": "9.91", "ESA loss at 500th cycle (%)": "73.6" } JSON for Catalyst PtCr/C: { "j at 0.6V (mA/cm2)": "358.8", "-b (mV/Dec)": "55.0", "j 0 (mA/cm2)": "1.20×10−5", "R (Ω-cm2)": "0.4500", "m (mV)": "5.4", "n (cm2/mA)": "0.0053", "R 2": "0.9991", "E corr (mV)": "−153", "b a (mV/dec)": "183", "b c (mV/dec)": "152", "j corr (mA/cm2)": "2.25", "ESA loss at 500th cycle (%)": "43.6" } JSON for Catalyst PtPd/C: { "j at 0.6V (mA/cm2)": "389.2", "-b (mV/Dec)": "59.6", "j 0 (mA/cm2)": "3.49×10−5", "R (Ω-cm2)": "0.3549", "m (mV)": "6.9", "n (cm2/mA)": "0.0051", "R 2": "0.9991", "E corr (mV)": "−195", "b a (mV/dec)": "434", "b c (mV/dec)": "258", "j corr (mA/cm2)": "6.51", "ESA loss at 500th cycle (%)": "60.0" } JSON for Catalyst PtCo/C: { "j at 0.6V (mA/cm2)": "392.8", "-b (mV/Dec)": "59.4", "j 0 (mA/cm2)": "3.68×10−5", "R (Ω-cm2)": "0.4047", "m (mV)": "2.7", "n (cm2/mA)": "0.0061", "R 2": "0.9989", "E corr (mV)": "−199", "b a (mV/dec)": "147", "b c (mV/dec)": "107", "j corr (mA/cm2)": "2.84", "ESA loss at 500th cycle (%)": "58.7" } JSON for Catalyst H-PtCr/C: { "j at 0.6V (mA/cm2)": "368.4", "-b (mV/Dec)": "51.0", "j 0 (mA/cm2)": "7.74×10−6", "R (Ω-cm2)": "0.5100", "m (mV)": "3.9", "n (cm2/mA)": "0.0054", "R 2": "0.9986", "E corr (mV)": "−154", "b a (mV/dec)": "223", "b c (mV/dec)": "195", "j corr (mA/cm2)": "1.74", "ESA loss at 500th cycle (%)": "41.7" } JSON for Catalyst H-PtPd/C: { "j at 0.6V (mA/cm2)": "344.8", "-b (mV/Dec)": "50.6", "j 0 (mA/cm2)": "5.98×10−6", "R (Ω-cm2)": "0.5500", "m (mV)": "1.9", "n (cm2/mA)": "0.0064", "R 2": "0.9992", "E corr (mV)": "−192", "b a (mV/dec)": "388", "b c (mV/dec)": "38", "j corr (mA/cm2)": "8.06", "ESA loss at 500th cycle (%)": "76.6" } JSON for Catalyst H-PtCo/C: { "j at 0.6V (mA/cm2)": "379.4", "-b (mV/Dec)": "52.0", "j 0 (mA/cm2)": "7.80×10−6", "R (Ω-cm2)": "0.4730", "m (mV)": "1.8", "n (cm2/mA)": "0.0065", "R 2": "0.9988", "E corr (mV)": "−186", "b a (mV/dec)": "159", "b c (mV/dec)": "124", "j corr (mA/cm2)": "2.68", "ESA loss at 500th cycle (%)": "48.6" }
# Processed and saved 10.1016-j.energy.2017.03.162.json to Data/PaperJson/JSON-All-Results

# %% [markdown]
# ## 4.2.2 Extract Complete "CPSP" Info by prompt engineering:
# #### Use the Code in 4.1.2.

# %% [markdown]
# ## 4.2.3 Sort out "CPSP" Info of different alloys into tabular files:

# %% [markdown]
# ### 1. Combine Main_Idea Json

# %%
import os
import chardet
import re
import json
import shutil

def detect_encoding(file_path):
    """Detect the file encoding"""
    with open(file_path, 'rb') as f:
        result = chardet.detect(f.read())
    return result['encoding']

def format_doi(filename):
    """Format the filename into a DOI"""
    doi = filename.replace("-", "/").replace(".json", "")
    return doi

def combine_main_ideas(path1, output_file, move_path):
    """Combine all main idea JSONs from the files in the directory into one file"""
    # Store all main ideas
    all_main_ideas = []
    
    # Iterate through all files in the directory
    for filename in os.listdir(path1):
        if filename.endswith('.json'):
            file_path = os.path.join(path1, filename)
            
            # Detect the file encoding
            encoding = detect_encoding(file_path)
            
            # Read the file content
            with open(file_path, 'r', encoding=encoding) as f:
                content = f.readlines()
            
            # Remove lines containing ```json and ```
            cleaned_lines = [line for line in content if "```json" not in line and "```" not in line]
            final_content = "".join(cleaned_lines)
            
            # Search and extract the content block containing "JSON for Main idea:"
            main_idea_match = re.search(r'JSON for Main idea:\s*({.*?})', final_content, re.DOTALL)
            
            if main_idea_match:
                main_idea_content = main_idea_match.group(1)
                
                try:
                    # Convert the extracted content into a dictionary
                    main_idea_data = json.loads(main_idea_content)
                    
                    # Add the formatted DOI field at the first position
                    formatted_doi = format_doi(filename)
                    main_idea_data = {"DOI": formatted_doi, **main_idea_data}
                    
                    # Add to the list
                    all_main_ideas.append(main_idea_data)
                    
                    print(f"Extracted 'Main idea' from: {filename}")
                
                except json.JSONDecodeError:
                    print(f"Error decoding 'Main idea' JSON in file: {filename}")
            else:
                # Move the file to a new path
                shutil.move(file_path, os.path.join(move_path, filename))
                print(f"Moved '{filename}' to '{move_path}'")

    # Create the final dictionary containing all main ideas
    final_json = {
        "main_ideas": all_main_ideas
    }
    
    # Save the combined JSON file
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(final_json, f, ensure_ascii=False, indent=4)
    
    print(f"\nSuccessfully combined {len(all_main_ideas)} main ideas into: {output_file}")

def count_main_ideas(file_path):
    """Count the number of JSON objects with a complete structure"""
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    count = 0
    for main_idea in data['main_ideas']:
        if all(key in main_idea for key in ["DOI", "research_object", "processing_route", "performance", "main idea"]):
            count += 1
    
    return count

# Example usage
source_path  = 'C:/Users/UNSW/Desktop/Alloy/HT/SN/JSON-CPSP'
output_json = 'C:/Users/UNSW/Desktop/Alloy/HT/SN/Mainidea-Combined.json'
move_path = 'C:/Users/UNSW/Desktop/Alloy/HT/SN/CPSP-NoMainidea'  # Path for files without main idea
combine_main_ideas(source_path, output_json, move_path)

# Count the number of main ideas with a complete structure in the output JSON file
count = count_main_ideas(output_json)
print(f"Number of main ideas with complete structure: {count}")
# Out:
# Processed: 10.1016-j.ijplas.2004.03.00271.json
# Processed: 10.1016-j.ijplas.2004.03.00271.json
# Processed: 10.1016-j.ijplas.2004.03.00271.json
# Processed: 10.1016-j.ijplas.2004.03.00222.json
# Processed: 10.1016-j.ijplas.2004.03.00222.json
# Processed: 10.1016-j.ijplas.2004.03.00222.json
# Processed: 10.1016-j.ijplas.2004.03.005.json
# Processed: 10.1016-j.ijplas.2004.03.005.json
# Processed: 10.1016-j.ijplas.2004.03.005.json
# All JSON blocks have been combined and saved to /Users/zixuanzhao/Desktop/Prompt+Example/AlloyGPT/Data/CustomizedTable/AllJSON.json

# %% [markdown]
# ### 2. Convert Main_Idea Json into tabular format

# %%
import json

# Read the JSON file
input_path = "/Users/zixuanzhao/Desktop/Prompt+Example/AlloyGPT/Prompt+Example/untitled folder2/All-CPSP-JSON2.json"
output_path = "/Users/zixuanzhao/Desktop/Prompt+Example/AlloyGPT/Prompt+Example/untitled folder2/All-CPSP-JSON2.txt"

with open(input_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

# Convert each JSON object to a tabular format in a single line
with open(output_path, 'w', encoding='utf-8') as f_out:
    for item in data["main_ideas"]:
        # Convert each key-value pair to the format "key|value"
        line = "|".join([f"{key}|{value}" for key, value in item.items()])
        # Write to the file, with each JSON object occupying one line
        f_out.write(line + "\n")

print(f"Conversion complete, output to file: {output_path}")
# Out:
# 转换完成，输出到文件：/Users/zixuanzhao/Desktop/Prompt+Example/AlloyGPT/CombinedMainidea2.txt

# %% [markdown]
#  ### 3. Combine CPSP Json

# %%
import os
import chardet
import re

def detect_encoding(file_path):
    """Detect the file encoding"""
    with open(file_path, 'rb') as f:
        result = chardet.detect(f.read())
    return result['encoding']

def format_doi(filename):
    """Format the filename into a DOI"""
    return filename.replace("-", "/").replace(".json", "")

def clean_and_format_json_blocks(path1, alljson_path):
    """Clean and format JSON blocks from files in the directory, then combine them into one file"""
    all_json_data = []  # Store all processed JSON blocks

    # Iterate through all files in the specified directory
    for filename in os.listdir(path1):
        if filename.endswith('.json'):
            file_path = os.path.join(path1, filename)

            # Detect the file encoding
            encoding = detect_encoding(file_path)

            # Read the file content
            with open(file_path, 'r', encoding=encoding) as f:
                content = f.read()

            # Remove lines containing ```json and ```
            cleaned_content = re.sub(r'```json\s*|```', '', content)

            # Delete the "JSON for Main idea:" block and its content
            cleaned_content = re.sub(r'JSON for Main idea:\s*\{.*?\}', '', cleaned_content, flags=re.DOTALL)

            # Generate a formatted DOI string
            formatted_doi = format_doi(filename)

            # Add the DOI to each JSON block, ensuring a newline after the DOI
            modified_content = re.sub(
                r'(JSON for [^:]+:\s*\{)',
                rf'\1\n  "DOI": "{formatted_doi}",',
                cleaned_content
            )

            # Add the processed content to the list
            all_json_data.append(modified_content.strip())
            print(f"Processed: {filename}")

    # Combine all JSON data into a single file with an empty line between each block
    with open(alljson_path, 'w', encoding='utf-8') as f:
        f.write("\n\n".join(all_json_data))
    
    print(f"All JSON blocks have been combined and saved to {alljson_path}")

# Example usage
path1 = 'C:/Users/UNSW/Desktop/Alloy/HT/CPSP-Results/3'
alljson_path = 'C:/Users/UNSW/Desktop/Alloy/HT/CPSP-Results/All-CPSP-JSON.json'
clean_and_format_json_blocks(path1, alljson_path)
# Out:
# Processed: 10.1016:j.msea.2016.05.016.json
# Processed: 10.1007-s11665-021-05930-x.json
# Processed: 10.1007-s11665-021-05930-x copy.json
# All JSON blocks have been combined and saved to /Users/zixuanzhao/Desktop/Prompt+Example/AlloyGPT/Prompt+Example/untitled folder2/All-CPSP-JSON.json

# %% [markdown]
# ### 4. Clean Combined CPSP JSON

# %%
import re

def clean_json_format(alljson_path, cleaned_json_path):
    with open(alljson_path, 'r', encoding='utf-8') as f:
        content = f.read()
    
    # Remove leading spaces and newlines from DOI, and combine DOI and composition on the same line
    content = re.sub(
        r'\{\s*"DOI":\s*"([^"]+)",\s*"composition":\s*"([^"]+)"',
        r'{"DOI": "\1", "composition": "\2"',
        content
    )
    
    # Remove keys with value "N/A", including cases where there is no comma after the key-value pair
    content = re.sub(r',?\s*"[a-zA-Z0-9_’‘’\-\s]+":\s*"N/A"\s*', '', content)
    
    # Remove empty objects, such as "corrosion_properties": {}
    content = re.sub(r',?\s*"[a-zA-Z0-9_’‘’\-\s]+":\s*\{\s*\}', '', content)
    
    # Clean up extra commas, commas in empty curly braces, and excessive newlines
    content = re.sub(r'\{\s*,\s*', '{', content)
    content = re.sub(r',\s*\}', '}', content)
    content = re.sub(r'\n\s*\n', '\n', content)

    # Ensure each JSON field is on a separate line and clean up excess whitespace
    content = re.sub(r',\s*"', ',\n"', content)
    content = re.sub(r'{\s*"', '{\n"', content)
    content = re.sub(r'"\s*}', '"\n}', content)

    # Write the cleaned content to a new file
    with open(cleaned_json_path, 'w', encoding='utf-8') as f:
        f.write(content)

    print(f"Cleaned JSON content has been saved to {cleaned_json_path}")

# Updated paths
alljson_path = '/Users/zixuanzhao/Desktop/Prompt+Example/AlloyGPT/Prompt+Example/untitled folder2/All-CPSP-JSON.json'
cleaned_json_path = '/Users/zixuanzhao/Desktop/Prompt+Example/AlloyGPT/Prompt+Example/untitled folder2/All-CPSP-JSON2.json'
clean_json_format(alljson_path, cleaned_json_path)
# Out:
# Cleaned JSON content has been saved to /Users/zixuanzhao/Desktop/Prompt+Example/AlloyGPT/Prompt+Example/untitled folder2/All-CPSP-JSON2.json

# %% [markdown]
# ### 5. Convert Combined-CPSP.json into tabular file

# %%
# 输入和输出文件路径
input_file = "/Users/zixuanzhao/Desktop/Prompt+Example/AlloyGPT/Prompt+Example/untitled folder2/CPSP-Formatted_Results3.json"  # 输入文件路径
output_file = "/Users/zixuanzhao/Desktop/Prompt+Example/AlloyGPT/Prompt+Example/untitled folder2/CPSP-Formatted_Results4.json"  # 输出文件路径

# 处理文件
with open(input_file, "r", encoding="utf-8") as infile, open(output_file, "w", encoding="utf-8") as outfile:
    buffer = ""
    for line in infile:
        # 去掉空行和换行符
        line = line.strip()
        if line:
            # 检查是否以 "JSON for ...:" 开头并替换为 "Sample Name: ..."
            if line.startswith("JSON for ") and ":" in line:
                # 将 "JSON for " 替换为 "#Sample Name# " 并删除最后一个冒号
                line = line.replace("JSON for ", "#Sample Name# ", 1)
                line = line.rstrip(":")
            
            # 检查并替换 {"DOI": " 为 #DOI#
            if '{"DOI": "' in line:
                line = line.replace('{"DOI": "', '#DOI#').replace('",', '#,', 1)  # 替换第一个 DOI 出现
                            
            # 检查并替换 #, "Composition": " 为 #Composition#
            if '#, "Composition": "' in line:
                line = line.replace('#, "Composition": "', '#Composition#')
            
            # 累积内容到 buffer
            buffer += line + " "
        else:
            # 遇到空行，保存当前 buffer 到输出文件并清空 buffer
            if buffer.strip():  # 忽略空 buffer
                outfile.write(buffer.strip() + "\n")
                buffer = ""
    # 处理文件末尾的剩余内容
    if buffer.strip():
        outfile.write(buffer.strip() + "\n")

print(f"转换完成，结果保存到 {output_file}")
# Out:
# 转换完成，结果保存到 /Users/zixuanzhao/Desktop/Prompt+Example/AlloyGPT/Prompt+Example/untitled folder2/CPSP-Formatted_Results4.json

# %%
# 输入和输出文件路径
input_file = "/Users/zixuanzhao/Desktop/Prompt+Example/AlloyGPT/Prompt+Example/untitled folder2/CPSP-Formatted_Results3.json"  # 输入文件路径
output_file = "/Users/zixuanzhao/Desktop/Prompt+Example/AlloyGPT/Prompt+Example/untitled folder2/CPSP-Formatted_Results4.json"  # 输出文件路径

# 处理文件
with open(input_file, "r", encoding="utf-8") as infile, open(output_file, "w", encoding="utf-8") as outfile:
    buffer = ""
    for line in infile:
        # 去掉空行和换行符
        line = line.strip()
        
        if line:
            # 检查是否以 "JSON for ...:" 开头并替换为 "Sample Name: ..."
            if line.startswith("JSON for ") and ":" in line:
                # 将 "JSON for " 替换为 "#Sample Name# " 并删除最后一个冒号
                line = line.replace("JSON for ", "#Sample Name# ", 1)
                line = line.rstrip(":")
                
            # 检查并替换 {"DOI": " 为 #DOI#
            if '{"DOI": "' in line:
                # 替换 {"DOI": " 为 #DOI# 并移除后面的空格
                line = line.replace('{"DOI": "', '#DOI#').replace('",', '#', 1)
                line = line.replace("# ", "#")  # 删除 # 后可能存在的空格

            # 检查并替换 #, "Composition": " 为 #Composition#
            if '#, "Composition": "' in line:
                line = line.replace('#, "Composition": "', '#Composition#')
            
            # 累积内容到 buffer
            buffer += line + " "
        else:
            # 遇到空行，保存当前 buffer 到输出文件并清空 buffer
            if buffer.strip():  # 忽略空 buffer
                outfile.write(buffer.strip() + "\n")
                buffer = ""
    # 处理文件末尾的剩余内容
    if buffer.strip():
        outfile.write(buffer.strip() + "\n")

print(f"转换完成，结果保存到 {output_file}")
# Out:
# 转换完成，结果保存到 /Users/zixuanzhao/Desktop/Prompt+Example/AlloyGPT/Prompt+Example/untitled folder2/CPSP-Formatted_Results4.json
